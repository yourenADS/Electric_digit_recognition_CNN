# %%
import cv2
import numpy as np
import pandas as pd
import os
from PIL import Image

def process_meter_images(data_root='train'):
    """处理CSV文件中指定的所有电表图像，并切分数字"""
    # 创建输出目录
    csv_path = f'{data_root}/data_detect.csv'  # CSV文件路径
    image_dir = f"{data_root}/Dataset"      # 图像文件夹路径
    output_dir=f"{data_root}/Dataset_process1"
    cut_dir=f"{data_root}/cut_num"
    for dir_path in [output_dir, cut_dir]:
        if not os.path.exists(dir_path):
            os.makedirs(dir_path)
    
    # 读取CSV文件
    df = pd.read_csv(csv_path)
    
    results = []
    
    # 遍历CSV中的每一行
    for _, row in df.iterrows():
        filename = row['filename']
        number_str = str(row['number'])  # 保留小数点，用于确定小数点位
        
        # 提取整数部分和小数部分
        if '.' in number_str:
            integer_part, decimal_part = number_str.split('.')
        else:
            integer_part = number_str
            decimal_part = ''
        
        # 构建完整数字字符串（补零到6位）
        full_number = f"{integer_part}{decimal_part}".zfill(6)
        
        xmin, ymin, xmax, ymax = row['xmin'], row['ymin'], row['xmax'], row['ymax']
        
        # 构建图像路径
        image_path = os.path.join(image_dir, filename)
        
        try:
            # 处理图像
            original_img, processed_img, digit_roi = process_single_image(image_path, xmin, ymin, xmax, ymax)
            
            # 切分数字（固定6个，索引从右到左）
            cut_digits = split_fixed_digits(digit_roi, full_number, os.path.join(cut_dir, filename))
            
            # 保存结果
            cv2.imwrite(os.path.join(output_dir, f"processed_{filename}"), processed_img)
            cv2.imwrite(os.path.join(output_dir, f"roi_{filename}"), digit_roi)
            
            results.append({
                'filename': filename,
                'number': full_number,
                'image': processed_img,
                'roi': digit_roi,
                'cut_digits': cut_digits
            })
            
            print(f"成功处理: {filename} -> {full_number}")
        except Exception as e:
            print(f"处理失败: {filename}, 错误: {str(e)}")
    
    return results

def process_single_image(image_path, xmin, ymin, xmax, ymax):
    """处理单张图像并提取读数区域"""
    # 读取图像
    img = cv2.imread(image_path)
    
    # 图像预处理 - 去反光
    corrected_img = reduce_reflection(img)
    
    # 提取读数区域
    digit_roi = corrected_img[ymin:ymax, xmin:xmax]
    
    # 增强数字区域对比度
    enhanced_roi = enhance_contrast(digit_roi)
    
    return img, corrected_img, enhanced_roi

def reduce_reflection(img):
    """减少图像反光"""
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    result = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    return result

def enhance_contrast(img):
    """增强图像对比度"""
    if len(img.shape) == 3:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    else:
        gray = img
    
    blur = cv2.GaussianBlur(gray, (3, 3), 0)
    thresh = cv2.adaptiveThreshold(
        blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 2
    )
    
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 2))
    opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=1)
    
    return opening

def split_fixed_digits(roi, number_str, output_prefix):
    """将ROI固定切分为6个数字区域（索引从右到左）"""
    # 确保数字字符串长度为6
    if len(number_str) > 6:
        number_str = number_str[-6:]  # 截取最后6位
    elif len(number_str) < 6:
        number_str = number_str.zfill(6)  # 左侧补零到6位
    
    # 获取ROI宽度并计算每个数字的大致宽度
    roi_height, roi_width = roi.shape[:2]
    digit_width = roi_width // 6
    
    cut_digits = []
    
    # 切分并保存6个数字（索引从右到左）
    for i in range(6):
        # 从右到左映射索引
        reversed_index = 5 - i
        
        # 计算数字区域的左右边界
        start_x = reversed_index * digit_width
        end_x = (reversed_index + 1) * digit_width
        
        # 提取数字区域并添加边距
        margin = 2
        digit_roi = roi[:, max(0, start_x-margin):min(end_x+margin, roi_width)]
        
        # 获取对应的数字标签
        digit_value = number_str[reversed_index]
        
        # 保存切分的数字（索引从右到左）
        output_path = f"{output_prefix}_{i}_{digit_value}.jpg"
        cv2.imwrite(output_path, digit_roi)
        cut_digits.append((i, digit_value, digit_roi))
    
    return cut_digits

# %%
# 处理所有图像
results = process_meter_images('train')
    
print(f"处理完成，共处理{len(results)}张图像")
# Out:
# 成功处理: hefei_3188.jpg -> 095759
# 成功处理: hefei_3190.jpg -> 196520
# 成功处理: hefei_3191.jpg -> 022627
# 成功处理: hefei_3192.jpg -> 057020
# 成功处理: hefei_3194.jpg -> 025660
# 成功处理: hefei_3195.jpg -> 075097
# 成功处理: hefei_3196.jpg -> 002723
# 成功处理: hefei_3198.jpg -> 183045
# 成功处理: hefei_3199.jpg -> 079032
# 成功处理: hefei_3200.jpg -> 059815
# 成功处理: hefei_3203.jpg -> 019230
# 成功处理: hefei_3204.jpg -> 067635
# 成功处理: hefei_3205.jpg -> 125458
# 成功处理: hefei_3208.jpg -> 055985
# 成功处理: hefei_3209.jpg -> 055467
# 成功处理: hefei_3210.jpg -> 064021
# 成功处理: hefei_3212.jpg -> 034674
# 成功处理: hefei_3213.jpg -> 000827
# 成功处理: hefei_3214.jpg -> 112906
# 成功处理: hefei_3216.jpg -> 031849
# 成功处理: hefei_3217.jpg -> 063259
# 成功处理: hefei_3218.jpg -> 090412
# 成功处理: hefei_3220.jpg -> 102934
# 成功处理: hefei_3221.jpg -> 041353
# 成功处理: hefei_3222.jpg -> 036731
# 成功处理: hefei_3224.jpg -> 348976
# 成功处理: hefei_3225.jpg -> 120402
# 成功处理: hefei_3226.jpg -> 002084
# 成功处理: hefei_3228.jpg -> 107204
# 成功处理: hefei_3229.jpg -> 030739
# 成功处理: hefei_3230.jpg -> 126352
# 成功处理: hefei_3232.jpg -> 050302
# 成功处理: hefei_3233.jpg -> 031583
# 成功处理: hefei_3236.jpg -> 039025
# 成功处理: hefei_3237.jpg -> 133462
# 成功处理: hefei_3238.jpg -> 134866
# 成功处理: hefei_3240.jpg -> 048200
# 成功处理: hefei_3241.jpg -> 020411
# 成功处理: hefei_3242.jpg -> 063963
# 成功处理: hefei_3244.jpg -> 108155
# 成功处理: hefei_3245.jpg -> 034104
# 成功处理: hefei_3246.jpg -> 027821
# 成功处理: hefei_3248.jpg -> 044484
# 成功处理: hefei_3249.jpg -> 031496
# 成功处理: hefei_3250.jpg -> 071511
# 成功处理: hefei_3252.jpg -> 034976
# 成功处理: hefei_3253.jpg -> 076144
# 成功处理: hefei_3254.jpg -> 130006
# 成功处理: hefei_3256.jpg -> 023339
# 成功处理: hefei_3257.jpg -> 114963
# 成功处理: hefei_3258.jpg -> 129918
# 成功处理: hefei_3260.jpg -> 086106
# 成功处理: hefei_3261.jpg -> 010570
# 成功处理: hefei_3262.jpg -> 072279
# 成功处理: hefei_3264.jpg -> 095939
# 成功处理: hefei_3265.jpg -> 060758
# 成功处理: hefei_3266.jpg -> 120459
# 成功处理: hefei_3268.jpg -> 111689
# 成功处理: hefei_3269.jpg -> 036319
# 成功处理: hefei_3270.jpg -> 084544
# 成功处理: hefei_3272.jpg -> 059599
# 成功处理: hefei_3273.jpg -> 009749
# 成功处理: hefei_3274.jpg -> 063205
# 成功处理: hefei_3276.jpg -> 073159
# 成功处理: hefei_3277.jpg -> 128458
# 成功处理: hefei_3278.jpg -> 061333
# 成功处理: hefei_3280.jpg -> 032190
# 成功处理: hefei_3281.jpg -> 188818
# 成功处理: hefei_3282.jpg -> 043076
# 成功处理: hefei_3284.jpg -> 123011
# 成功处理: hefei_3285.jpg -> 067549
# 成功处理: hefei_3288.jpg -> 077486
# 成功处理: hefei_3289.jpg -> 135146
# 成功处理: hefei_3290.jpg -> 050732
# 成功处理: hefei_3292.jpg -> 048499
# 成功处理: hefei_3293.jpg -> 018402
# 成功处理: hefei_3294.jpg -> 099083
# 成功处理: hefei_3296.jpg -> 037952
# 成功处理: hefei_3297.jpg -> 074492
# 成功处理: hefei_3298.jpg -> 321386
# 成功处理: hefei_3300.jpg -> 100138
# 成功处理: hefei_3301.jpg -> 109147
# 成功处理: hefei_3302.jpg -> 074705
# 成功处理: hefei_3304.jpg -> 031438
# 成功处理: hefei_3305.jpg -> 068478
# 成功处理: hefei_3306.jpg -> 066856
# 成功处理: hefei_3308.jpg -> 098913
# 成功处理: hefei_3309.jpg -> 023508
# 成功处理: hefei_3310.jpg -> 067877
# 成功处理: hefei_3312.jpg -> 096940
# 成功处理: hefei_3313.jpg -> 099497
# 成功处理: hefei_3314.jpg -> 028633
# 成功处理: hefei_3316.jpg -> 071663
# 成功处理: hefei_3317.jpg -> 219743
# 成功处理: hefei_3318.jpg -> 095375
# 成功处理: hefei_3320.jpg -> 150017
# 成功处理: hefei_3321.jpg -> 031565
# 成功处理: hefei_3322.jpg -> 148165
# 成功处理: hefei_3324.jpg -> 023788
# 成功处理: hefei_3325.jpg -> 063791
# 成功处理: hefei_3326.jpg -> 035753
# 成功处理: hefei_3328.jpg -> 084123
# 成功处理: hefei_3329.jpg -> 059962
# 成功处理: hefei_3330.jpg -> 059185
# 成功处理: hefei_3332.jpg -> 139689
# 成功处理: hefei_3333.jpg -> 071741
# 成功处理: hefei_3334.jpg -> 079629
# 成功处理: hefei_3336.jpg -> 101318
# 成功处理: hefei_3337.jpg -> 042082
# 成功处理: hefei_3338.jpg -> 101854
# 成功处理: hefei_3340.jpg -> 151142
# 成功处理: hefei_3341.jpg -> 076215
# 成功处理: hefei_3342.jpg -> 050953
# 成功处理: hefei_3344.jpg -> 027261
# 成功处理: hefei_3345.jpg -> 032522
# 成功处理: hefei_3346.jpg -> 090754
# 成功处理: hefei_3348.jpg -> 061651
# 成功处理: hefei_3349.jpg -> 028278
# 成功处理: hefei_3350.jpg -> 035820
# 成功处理: hefei_3352.jpg -> 052763
# 成功处理: hefei_3353.jpg -> 082158
# 成功处理: hefei_3354.jpg -> 199955
# 成功处理: hefei_3356.jpg -> 091379
# 成功处理: hefei_3357.jpg -> 193171
# 成功处理: hefei_3358.jpg -> 107122
# 成功处理: hefei_3360.jpg -> 074783
# 成功处理: hefei_3361.jpg -> 069304
# 成功处理: hefei_3362.jpg -> 063513
# 成功处理: hefei_3364.jpg -> 023846
# 成功处理: hefei_3365.jpg -> 039500
# 成功处理: hefei_3366.jpg -> 051380
# 成功处理: hefei_3368.jpg -> 002472
# 成功处理: hefei_3369.jpg -> 064058
# 成功处理: hefei_3370.jpg -> 033272
# 成功处理: hefei_3372.jpg -> 037969
# 成功处理: hefei_3373.jpg -> 102782
# 成功处理: hefei_3374.jpg -> 083449
# 成功处理: hefei_3376.jpg -> 240211
# 成功处理: hefei_3377.jpg -> 011703
# 成功处理: hefei_3378.jpg -> 026532
# 成功处理: hefei_3380.jpg -> 059127
# 成功处理: hefei_3381.jpg -> 027219
# 成功处理: hefei_3382.jpg -> 115409
# 成功处理: hefei_3384.jpg -> 122758
# 成功处理: hefei_3385.jpg -> 155177
# 成功处理: hefei_3386.jpg -> 031841
# 成功处理: hefei_3388.jpg -> 020403
# 成功处理: hefei_3389.jpg -> 000000
# 成功处理: hefei_3390.jpg -> 057902
# 成功处理: hefei_3393.jpg -> 049098
# 成功处理: hefei_3394.jpg -> 087072
# 成功处理: hefei_3395.jpg -> 068413
# 成功处理: hefei_3397.jpg -> 074536
# 成功处理: hefei_3398.jpg -> 085689
# 成功处理: hefei_3399.jpg -> 022572
# 成功处理: hefei_3401.jpg -> 073786
# 成功处理: hefei_3402.jpg -> 067942
# 成功处理: hefei_3403.jpg -> 060650
# 成功处理: hefei_3406.jpg -> 077487
# 成功处理: hefei_3407.jpg -> 075174
# 成功处理: hefei_3408.jpg -> 074671
# 成功处理: hefei_3410.jpg -> 021253
# 成功处理: hefei_3411.jpg -> 024326
# 成功处理: hefei_3412.jpg -> 098583
# 成功处理: hefei_3414.jpg -> 061073
# 成功处理: hefei_3415.jpg -> 020856
# 成功处理: hefei_3416.jpg -> 103112
# 成功处理: hefei_3418.jpg -> 215913
# 成功处理: hefei_3419.jpg -> 096933
# 成功处理: hefei_3420.jpg -> 076874
# 成功处理: hefei_3422.jpg -> 071585
# 成功处理: hefei_3423.jpg -> 080782
# 成功处理: hefei_3424.jpg -> 086875
# 成功处理: hefei_3426.jpg -> 204323
# 成功处理: hefei_3427.jpg -> 059995
# 成功处理: hefei_3428.jpg -> 021156
# 成功处理: hefei_3430.jpg -> 001206
# 成功处理: hefei_3431.jpg -> 121109
# 成功处理: hefei_3432.jpg -> 086156
# 成功处理: hefei_3434.jpg -> 060651
# 成功处理: hefei_3435.jpg -> 032560
# 成功处理: hefei_3436.jpg -> 073899
# 成功处理: hefei_3438.jpg -> 007824
# 成功处理: hefei_3439.jpg -> 010928
# 成功处理: hefei_3440.jpg -> 122899
# 成功处理: hefei_3442.jpg -> 023954
# 成功处理: hefei_3443.jpg -> 081233
# 成功处理: hefei_3444.jpg -> 024936
# 成功处理: hefei_3446.jpg -> 086698
# 成功处理: hefei_3447.jpg -> 061042
# 成功处理: hefei_3448.jpg -> 034599
# 成功处理: hefei_3450.jpg -> 122347
# 成功处理: hefei_3451.jpg -> 034715
# 成功处理: hefei_3452.jpg -> 117262
# 成功处理: hefei_3454.jpg -> 182339
# 成功处理: hefei_3455.jpg -> 026067
# 成功处理: hefei_3456.jpg -> 065878
# 成功处理: hefei_3458.jpg -> 057844
# 成功处理: hefei_3459.jpg -> 119702
# 成功处理: hefei_3460.jpg -> 057489
# 成功处理: hefei_3462.jpg -> 022894
# 成功处理: hefei_3463.jpg -> 022001
# 成功处理: hefei_3464.jpg -> 076947
# 成功处理: hefei_3466.jpg -> 034106
# 成功处理: hefei_3467.jpg -> 020588
# 成功处理: hefei_3468.jpg -> 088537
# 成功处理: hefei_3470.jpg -> 082672
# 成功处理: hefei_3471.jpg -> 020636
# 成功处理: hefei_3472.jpg -> 019763
# 成功处理: hefei_3474.jpg -> 039709
# 成功处理: hefei_3475.jpg -> 039457
# 成功处理: hefei_3476.jpg -> 109975
# 成功处理: hefei_3478.jpg -> 032357
# 成功处理: hefei_3479.jpg -> 049952
# 成功处理: hefei_3480.jpg -> 075435
# 成功处理: hefei_3482.jpg -> 095293
# 成功处理: hefei_3483.jpg -> 032364
# 成功处理: hefei_3484.jpg -> 032122
# 成功处理: hefei_3486.jpg -> 124392
# 成功处理: hefei_3487.jpg -> 071941
# 成功处理: hefei_3488.jpg -> 028744
# 成功处理: hefei_3490.jpg -> 171614
# 成功处理: hefei_3491.jpg -> 030554
# 成功处理: hefei_3492.jpg -> 021468
# 成功处理: hefei_3495.jpg -> 075326
# 成功处理: hefei_3496.jpg -> 143150
# 成功处理: hefei_3497.jpg -> 067966
# 成功处理: hefei_3499.jpg -> 038280
# 成功处理: hefei_3500.jpg -> 067883
# 成功处理: hefei_3501.jpg -> 180763
# 成功处理: hefei_3503.jpg -> 020832
# 成功处理: hefei_3504.jpg -> 067115
# 成功处理: hefei_3505.jpg -> 053422
# 成功处理: hefei_3507.jpg -> 074530
# 成功处理: hefei_3508.jpg -> 024355
# 成功处理: hefei_3509.jpg -> 063120
# 成功处理: hefei_3511.jpg -> 050917
# 成功处理: hefei_3512.jpg -> 071247
# 成功处理: hefei_3513.jpg -> 066023
# 成功处理: hefei_3515.jpg -> 143251
# 成功处理: hefei_3516.jpg -> 060131
# 成功处理: hefei_3517.jpg -> 041299
# 成功处理: hefei_3519.jpg -> 072232
# 成功处理: hefei_3520.jpg -> 039643
# 成功处理: hefei_3521.jpg -> 023075
# 成功处理: hefei_3523.jpg -> 124312
# 成功处理: hefei_3524.jpg -> 112938
# 成功处理: hefei_3525.jpg -> 071019
# 成功处理: hefei_3527.jpg -> 033110
# 成功处理: hefei_3528.jpg -> 069497
# 成功处理: hefei_3529.jpg -> 026405
# 成功处理: hefei_3531.jpg -> 007313
# 成功处理: hefei_3532.jpg -> 161234
# 成功处理: hefei_3533.jpg -> 123431
# 成功处理: hefei_3535.jpg -> 123843
# 成功处理: hefei_3536.jpg -> 061451
# 成功处理: hefei_3537.jpg -> 035783
# 成功处理: hefei_3539.jpg -> 139935
# 成功处理: hefei_3540.jpg -> 111133
# 成功处理: hefei_3541.jpg -> 045372
# 成功处理: hefei_3543.jpg -> 069337
# 成功处理: hefei_3544.jpg -> 029937
# 成功处理: hefei_3545.jpg -> 033582
# 成功处理: hefei_3547.jpg -> 058029
# 成功处理: hefei_3548.jpg -> 054746
# 成功处理: hefei_3549.jpg -> 006808
# 成功处理: hefei_3551.jpg -> 129513
# 成功处理: hefei_3552.jpg -> 061956
# 成功处理: hefei_3553.jpg -> 068564
# 成功处理: hefei_3555.jpg -> 021134
# 成功处理: hefei_3556.jpg -> 029215
# 成功处理: hefei_3557.jpg -> 034523
# 成功处理: hefei_3559.jpg -> 114469
# 成功处理: hefei_3560.jpg -> 176421
# 成功处理: hefei_3561.jpg -> 243988
# 成功处理: hefei_3563.jpg -> 137254
# 成功处理: hefei_3564.jpg -> 035714
# 成功处理: hefei_3565.jpg -> 082788
# 成功处理: hefei_3567.jpg -> 061148
# 成功处理: hefei_3568.jpg -> 024728
# 成功处理: hefei_3569.jpg -> 071950
# 成功处理: hefei_3571.jpg -> 239643
# 成功处理: hefei_3572.jpg -> 007039
# 成功处理: hefei_3573.jpg -> 009615
# 成功处理: hefei_3575.jpg -> 084947
# 成功处理: hefei_3576.jpg -> 145728
# 成功处理: hefei_3577.jpg -> 008085
# 成功处理: hefei_3579.jpg -> 138887
# 成功处理: hefei_3580.jpg -> 120672
# 成功处理: hefei_3581.jpg -> 062873
# 成功处理: hefei_3583.jpg -> 138076
# 成功处理: hefei_3584.jpg -> 087082
# 成功处理: hefei_3585.jpg -> 044199
# 成功处理: hefei_3587.jpg -> 151125
# 成功处理: hefei_3588.jpg -> 026267
# 成功处理: hefei_3589.jpg -> 074266
# 成功处理: hefei_3591.jpg -> 064416
# 成功处理: hefei_3592.jpg -> 150728
# 成功处理: hefei_3593.jpg -> 029576
# 成功处理: hefei_3595.jpg -> 049738
# 成功处理: hefei_3596.jpg -> 021608
# 成功处理: hefei_3597.jpg -> 116686
# 成功处理: hefei_3599.jpg -> 500969
# 成功处理: hefei_3600.jpg -> 021163
# 成功处理: hefei_3601.jpg -> 032658
# 成功处理: hefei_3603.jpg -> 081278
# 成功处理: hefei_3604.jpg -> 152376
# 成功处理: hefei_3605.jpg -> 057215
# 成功处理: hefei_3607.jpg -> 033374
# 成功处理: hefei_3608.jpg -> 018134
# 成功处理: hefei_3609.jpg -> 110786
# 成功处理: hefei_3612.jpg -> 075080
# 成功处理: hefei_3613.jpg -> 009279
# 成功处理: hefei_3615.jpg -> 179210
# 成功处理: hefei_3616.jpg -> 092320
# 成功处理: hefei_3617.jpg -> 031652
# 成功处理: hefei_3619.jpg -> 062731
# 成功处理: hefei_3620.jpg -> 140935
# 成功处理: hefei_3621.jpg -> 152209
# 成功处理: hefei_3623.jpg -> 081353
# 成功处理: hefei_3624.jpg -> 142901
# 成功处理: hefei_3625.jpg -> 066820
# 成功处理: hefei_3627.jpg -> 091025
# 成功处理: hefei_3628.jpg -> 115763
# 成功处理: hefei_3629.jpg -> 067428
# 成功处理: hefei_3631.jpg -> 064298
# 成功处理: hefei_3632.jpg -> 141973
# 成功处理: hefei_3633.jpg -> 006084
# 成功处理: hefei_3635.jpg -> 036468
# 成功处理: hefei_3636.jpg -> 072042
# 成功处理: hefei_3637.jpg -> 000004
# 成功处理: hefei_3639.jpg -> 070411
# 成功处理: hefei_3640.jpg -> 140446
# 成功处理: hefei_3641.jpg -> 035672
# 成功处理: hefei_3643.jpg -> 022792
# 成功处理: hefei_3644.jpg -> 021278
# 成功处理: hefei_3645.jpg -> 069713
# 成功处理: hefei_3647.jpg -> 016666
# 成功处理: hefei_3648.jpg -> 075454
# 成功处理: hefei_3649.jpg -> 068566
# 成功处理: hefei_3651.jpg -> 083298
# 成功处理: hefei_3652.jpg -> 030322
# 成功处理: hefei_3653.jpg -> 061672
# 成功处理: hefei_3655.jpg -> 116250
# 成功处理: hefei_3656.jpg -> 023124
# 成功处理: hefei_3657.jpg -> 025985
# 成功处理: hefei_3659.jpg -> 071441
# 成功处理: hefei_3660.jpg -> 033424
# 成功处理: hefei_3661.jpg -> 086671
# 成功处理: hefei_3663.jpg -> 034931
# 成功处理: hefei_3664.jpg -> 009392
# 成功处理: hefei_3665.jpg -> 058271
# 成功处理: hefei_3667.jpg -> 025927
# 成功处理: hefei_3668.jpg -> 062301
# 成功处理: hefei_3669.jpg -> 068358
# 成功处理: hefei_3671.jpg -> 053008
# 成功处理: hefei_3672.jpg -> 048466
# 成功处理: hefei_3673.jpg -> 016479
# 成功处理: hefei_3675.jpg -> 108128
# 成功处理: hefei_3676.jpg -> 074502
# 成功处理: hefei_3677.jpg -> 076884
# 成功处理: hefei_3679.jpg -> 035861
# 成功处理: hefei_3680.jpg -> 032292
# 成功处理: hefei_3681.jpg -> 061543
# 成功处理: hefei_3683.jpg -> 128633
# 成功处理: hefei_3684.jpg -> 008931
# 成功处理: hefei_3685.jpg -> 060481
# 成功处理: hefei_3687.jpg -> 117284
# 成功处理: hefei_3688.jpg -> 060537
# 成功处理: hefei_3689.jpg -> 080099
# 成功处理: hefei_3691.jpg -> 146178
# 成功处理: hefei_3692.jpg -> 034363
# 成功处理: hefei_3693.jpg -> 120883
# 成功处理: hefei_3695.jpg -> 079954
# 成功处理: hefei_3696.jpg -> 157457
# 成功处理: hefei_3697.jpg -> 044803
# 成功处理: hefei_3699.jpg -> 028581
# 成功处理: hefei_3700.jpg -> 020014
# 成功处理: hefei_3701.jpg -> 050785
# 成功处理: hefei_3703.jpg -> 071639
# 成功处理: hefei_3704.jpg -> 569295
# 成功处理: hefei_3705.jpg -> 068091
# 成功处理: hefei_3707.jpg -> 070265
# 成功处理: hefei_3708.jpg -> 426184
# 成功处理: hefei_3709.jpg -> 030626
# 成功处理: hefei_3711.jpg -> 070999
# 成功处理: hefei_3712.jpg -> 077070
# 成功处理: hefei_3713.jpg -> 067739
# 成功处理: hefei_3715.jpg -> 040853
# 成功处理: hefei_3716.jpg -> 074681
# 成功处理: hefei_3717.jpg -> 193563
# 成功处理: hefei_3719.jpg -> 067645
# 成功处理: hefei_3720.jpg -> 072570
# 成功处理: hefei_3721.jpg -> 033341
# 成功处理: hefei_3723.jpg -> 087935
# 成功处理: hefei_3724.jpg -> 063803
# 成功处理: hefei_3725.jpg -> 050434
# 成功处理: hefei_3727.jpg -> 100687
# 成功处理: hefei_3728.jpg -> 060260
# 成功处理: hefei_3729.jpg -> 144787
# 成功处理: hefei_3731.jpg -> 122786
# 成功处理: hefei_3732.jpg -> 070976
# 成功处理: hefei_3733.jpg -> 115230
# 成功处理: hefei_3735.jpg -> 061380
# 成功处理: hefei_3736.jpg -> 180131
# 成功处理: hefei_3737.jpg -> 007019
# 成功处理: hefei_3739.jpg -> 073092
# 成功处理: hefei_3740.jpg -> 074105
# 成功处理: hefei_3741.jpg -> 025135
# 成功处理: hefei_3743.jpg -> 104707
# 成功处理: hefei_3744.jpg -> 094313
# 成功处理: hefei_3745.jpg -> 115692
# 成功处理: hefei_3747.jpg -> 008785
# 成功处理: hefei_3748.jpg -> 020308
# 成功处理: hefei_3749.jpg -> 077654
# 成功处理: hefei_3751.jpg -> 065505
# 成功处理: hefei_3752.jpg -> 062071
# 成功处理: hefei_3753.jpg -> 147198
# 成功处理: hefei_3755.jpg -> 071299
# 成功处理: hefei_3756.jpg -> 073677
# 成功处理: hefei_3757.jpg -> 143080
# 成功处理: hefei_3759.jpg -> 041078
# 成功处理: hefei_3760.jpg -> 261999
# 成功处理: hefei_3761.jpg -> 033779
# 成功处理: hefei_3763.jpg -> 155587
# 成功处理: hefei_3764.jpg -> 064557
# 成功处理: hefei_3765.jpg -> 070915
# 成功处理: hefei_3767.jpg -> 179302
# 成功处理: hefei_3768.jpg -> 045677
# 成功处理: hefei_3769.jpg -> 060430
# 成功处理: hefei_3771.jpg -> 036097
# 成功处理: hefei_3772.jpg -> 038886
# 成功处理: hefei_3773.jpg -> 058822
# 成功处理: hefei_3775.jpg -> 096880
# 成功处理: hefei_3776.jpg -> 060931
# 成功处理: hefei_3777.jpg -> 110145
# 成功处理: hefei_3779.jpg -> 139499
# 成功处理: hefei_3780.jpg -> 334122
# 成功处理: hefei_3781.jpg -> 124939
# 成功处理: hefei_3783.jpg -> 060487
# 成功处理: hefei_3784.jpg -> 001786
# 成功处理: hefei_3785.jpg -> 143558
# 成功处理: hefei_3787.jpg -> 035526
# 成功处理: hefei_3788.jpg -> 053472
# 成功处理: hefei_3789.jpg -> 023356
# 成功处理: hefei_3791.jpg -> 068683
# 成功处理: hefei_3792.jpg -> 072499
# 成功处理: hefei_3793.jpg -> 069571
# 成功处理: hefei_3795.jpg -> 038770
# 成功处理: hefei_3796.jpg -> 072124
# 成功处理: hefei_3797.jpg -> 097511
# 成功处理: hefei_3799.jpg -> 082498
# 成功处理: hefei_3800.jpg -> 227464
# 成功处理: hefei_3801.jpg -> 024876
# 成功处理: hefei_3803.jpg -> 066478
# 成功处理: hefei_3804.jpg -> 103016
# 成功处理: hefei_3805.jpg -> 112464
# 成功处理: hefei_3808.jpg -> 074902
# 成功处理: hefei_3811.jpg -> 032154
# 成功处理: hefei_3812.jpg -> 077355
# 成功处理: hefei_3813.jpg -> 062265
# 成功处理: hefei_3816.jpg -> 059431
# 成功处理: hefei_3817.jpg -> 029099
# 成功处理: hefei_3819.jpg -> 116269
# 成功处理: hefei_3820.jpg -> 138990
# 成功处理: hefei_3821.jpg -> 065369
# 成功处理: hefei_3823.jpg -> 067271
# 成功处理: hefei_3824.jpg -> 071633
# 成功处理: hefei_3827.jpg -> 084356
# 成功处理: hefei_3828.jpg -> 018178
# 成功处理: hefei_3829.jpg -> 088416
# 成功处理: hefei_3831.jpg -> 057198
# 成功处理: hefei_3832.jpg -> 066684
# 成功处理: hefei_3833.jpg -> 020626
# 成功处理: hefei_3836.jpg -> 048582
# 成功处理: hefei_3837.jpg -> 190326
# 成功处理: hefei_3838.jpg -> 023009
# 成功处理: hefei_3840.jpg -> 097037
# 成功处理: hefei_3842.jpg -> 070067
# 成功处理: hefei_3844.jpg -> 194153
# 成功处理: hefei_3845.jpg -> 136333
# 成功处理: hefei_3846.jpg -> 019736
# 成功处理: hefei_3849.jpg -> 083424
# 成功处理: hefei_3850.jpg -> 151391
# 成功处理: hefei_3852.jpg -> 067484
# 成功处理: hefei_3853.jpg -> 241632
# 成功处理: hefei_3854.jpg -> 066397
# 成功处理: hefei_3857.jpg -> 158491
# 成功处理: hefei_3858.jpg -> 140227
# 成功处理: hefei_3860.jpg -> 108034
# 成功处理: hefei_3861.jpg -> 067569
# 成功处理: hefei_3862.jpg -> 143086
# 成功处理: hefei_3865.jpg -> 021399
# 成功处理: hefei_3866.jpg -> 138360
# 成功处理: hefei_3868.jpg -> 098064
# 成功处理: hefei_3869.jpg -> 068127
# 成功处理: hefei_3872.jpg -> 032044
# 成功处理: hefei_3874.jpg -> 069852
# 成功处理: hefei_3876.jpg -> 028203
# 成功处理: hefei_3878.jpg -> 060956
# 成功处理: hefei_3880.jpg -> 096023
# 成功处理: hefei_3881.jpg -> 061019
# 成功处理: hefei_3882.jpg -> 028666
# 成功处理: hefei_3884.jpg -> 081093
# 成功处理: hefei_3886.jpg -> 123554
# 成功处理: hefei_3888.jpg -> 032431
# 成功处理: hefei_3889.jpg -> 039645
# 成功处理: hefei_3890.jpg -> 021682
# 成功处理: hefei_3892.jpg -> 064359
# 成功处理: hefei_3894.jpg -> 023818
# 成功处理: hefei_3897.jpg -> 026107
# 成功处理: hefei_3898.jpg -> 077275
# 成功处理: hefei_3904.jpg -> 076375
# 成功处理: hefei_3906.jpg -> 072257
# 成功处理: hefei_3908.jpg -> 059675
# 成功处理: hefei_3909.jpg -> 123319
# 成功处理: hefei_3910.jpg -> 072129
# 成功处理: hefei_3913.jpg -> 025830
# 成功处理: hefei_3916.jpg -> 067803
# 成功处理: hefei_3917.jpg -> 068401
# 成功处理: hefei_3920.jpg -> 069887
# 成功处理: hefei_3921.jpg -> 060423
# 成功处理: hefei_3925.jpg -> 014149
# 成功处理: hefei_3928.jpg -> 033960
# 成功处理: hefei_3929.jpg -> 103212
# 成功处理: hefei_3930.jpg -> 000290
# 成功处理: hefei_3933.jpg -> 077142
# 成功处理: hefei_3936.jpg -> 113399
# 成功处理: hefei_3937.jpg -> 059620
# 成功处理: hefei_3938.jpg -> 033106
# 成功处理: hefei_3940.jpg -> 070893
# 成功处理: hefei_3941.jpg -> 027026
# 成功处理: hefei_3942.jpg -> 082668
# 成功处理: hefei_3944.jpg -> 057601
# 成功处理: hefei_3945.jpg -> 009350
# 成功处理: hefei_3946.jpg -> 063281
# 成功处理: hefei_3948.jpg -> 060153
# 成功处理: hefei_3949.jpg -> 064842
# 成功处理: hefei_3950.jpg -> 075455
# 成功处理: hefei_3954.jpg -> 034216
# 成功处理: hefei_3956.jpg -> 081692
# 成功处理: hefei_3957.jpg -> 051729
# 成功处理: hefei_3958.jpg -> 044603
# 成功处理: hefei_3960.jpg -> 009165
# 成功处理: hefei_3961.jpg -> 204277
# 成功处理: hefei_3962.jpg -> 127060
# 成功处理: hefei_3964.jpg -> 077393
# 成功处理: hefei_3965.jpg -> 037022
# 成功处理: hefei_3968.jpg -> 039323
# 成功处理: hefei_3970.jpg -> 141044
# 成功处理: hefei_3972.jpg -> 058832
# 成功处理: hefei_3973.jpg -> 024200
# 成功处理: hefei_3974.jpg -> 057825
# 成功处理: hefei_3977.jpg -> 112596
# 成功处理: hefei_3982.jpg -> 032817
# 成功处理: hefei_3986.jpg -> 035732
# 成功处理: hefei_3988.jpg -> 061196
# 成功处理: hefei_3989.jpg -> 022325
# 成功处理: hefei_3990.jpg -> 072948
# 成功处理: hefei_3996.jpg -> 115342
# 成功处理: hefei_3998.jpg -> 022883
# 成功处理: hefei_4000.jpg -> 060931
# 成功处理: hefei_4002.jpg -> 031618
# 成功处理: hefei_4004.jpg -> 060108
# 成功处理: hefei_4005.jpg -> 044258
# 成功处理: hefei_4009.jpg -> 005926
# 成功处理: hefei_4010.jpg -> 064804
# 成功处理: hefei_4012.jpg -> 016209
# 成功处理: hefei_4014.jpg -> 060037
# 成功处理: hefei_4018.jpg -> 083677
# 成功处理: hefei_4020.jpg -> 030688
# 成功处理: hefei_4021.jpg -> 025696
# 成功处理: hefei_4024.jpg -> 030217
# 成功处理: hefei_4025.jpg -> 439134
# 成功处理: hefei_4026.jpg -> 028597
# 成功处理: hefei_4028.jpg -> 017302
# 成功处理: hefei_4029.jpg -> 073263
# 成功处理: hefei_4030.jpg -> 093349
# 成功处理: hefei_4032.jpg -> 063452
# 成功处理: hefei_4037.jpg -> 058691
# 成功处理: hefei_4038.jpg -> 078179
# 成功处理: hefei_4042.jpg -> 074622
# 成功处理: hefei_4045.jpg -> 034218
# 成功处理: hefei_4047.jpg -> 275217
# 成功处理: hefei_4049.jpg -> 069484
# 成功处理: hefei_4050.jpg -> 036577
# 成功处理: hefei_4051.jpg -> 032921
# 成功处理: hefei_4055.jpg -> 071110
# 成功处理: hefei_4057.jpg -> 033355
# 成功处理: hefei_4058.jpg -> 060158
# 成功处理: hefei_4061.jpg -> 021816
# 成功处理: hefei_4062.jpg -> 078272
# 成功处理: hefei_4063.jpg -> 068266
# 成功处理: hefei_4065.jpg -> 024382
# 成功处理: hefei_4066.jpg -> 031580
# 成功处理: hefei_4069.jpg -> 043638
# 成功处理: hefei_4070.jpg -> 068701
# 成功处理: hefei_4071.jpg -> 061917
# 成功处理: hefei_4073.jpg -> 061682
# 成功处理: hefei_4074.jpg -> 071804
# 成功处理: hefei_4075.jpg -> 077865
# 成功处理: hefei_4077.jpg -> 058465
# 成功处理: hefei_4081.jpg -> 075684
# 成功处理: hefei_4082.jpg -> 051582
# 成功处理: hefei_4083.jpg -> 014916
# 成功处理: hefei_4086.jpg -> 124003
# 成功处理: hefei_4089.jpg -> 040568
# 成功处理: hefei_4090.jpg -> 028824
# 成功处理: hefei_4093.jpg -> 055411
# 成功处理: hefei_4094.jpg -> 063569
# 成功处理: hefei_4095.jpg -> 010117
# 成功处理: hefei_4097.jpg -> 060217
# 成功处理: hefei_4098.jpg -> 071205
# 成功处理: hefei_4099.jpg -> 060583
# 成功处理: hefei_4101.jpg -> 025652
# 成功处理: hefei_4102.jpg -> 262256
# 成功处理: hefei_4103.jpg -> 052896
# 成功处理: hefei_4105.jpg -> 085824
# 成功处理: hefei_4109.jpg -> 093621
# 成功处理: hefei_4110.jpg -> 033300
# 成功处理: hefei_4111.jpg -> 084633
# 成功处理: hefei_4113.jpg -> 025557
# 成功处理: hefei_4114.jpg -> 075056
# 成功处理: hefei_4115.jpg -> 019710
# 成功处理: hefei_4117.jpg -> 032340
# 成功处理: hefei_4118.jpg -> 033028
# 成功处理: hefei_4121.jpg -> 029394
# 成功处理: hefei_4125.jpg -> 017586
# 成功处理: hefei_4127.jpg -> 059996
# 成功处理: hefei_4129.jpg -> 054473
# 成功处理: hefei_4131.jpg -> 046666
# 成功处理: hefei_4133.jpg -> 023599
# 成功处理: hefei_4135.jpg -> 077643
# 成功处理: hefei_4138.jpg -> 089436
# 成功处理: hefei_4139.jpg -> 051095
# 成功处理: hefei_4141.jpg -> 055226
# 成功处理: hefei_4142.jpg -> 078499
# 成功处理: hefei_4143.jpg -> 017602
# 成功处理: hefei_4145.jpg -> 133519
# 成功处理: hefei_4146.jpg -> 023682
# 成功处理: hefei_4147.jpg -> 094092
# 成功处理: hefei_4149.jpg -> 059651
# 成功处理: hefei_4150.jpg -> 073899
# 成功处理: hefei_4151.jpg -> 051273
# 成功处理: hefei_4153.jpg -> 067336
# 成功处理: hefei_4154.jpg -> 043140
# 成功处理: hefei_4155.jpg -> 059810
# 成功处理: hefei_4161.jpg -> 043936
# 成功处理: hefei_4162.jpg -> 058117
# 成功处理: hefei_4163.jpg -> 069783
# 成功处理: hefei_4165.jpg -> 026092
# 成功处理: hefei_4166.jpg -> 088053
# 成功处理: hefei_4167.jpg -> 057391
# 成功处理: hefei_4170.jpg -> 060714
# 成功处理: hefei_4171.jpg -> 032089
# 成功处理: hefei_4173.jpg -> 037483
# 成功处理: hefei_4175.jpg -> 025085
# 成功处理: hefei_4178.jpg -> 097280
# 成功处理: hefei_4181.jpg -> 021442
# 成功处理: hefei_4183.jpg -> 075201
# 成功处理: hefei_4185.jpg -> 040861
# 成功处理: hefei_4186.jpg -> 037052
# 成功处理: hefei_4187.jpg -> 014347
# 成功处理: hefei_4189.jpg -> 013085
# 成功处理: hefei_4190.jpg -> 012476
# 成功处理: hefei_4191.jpg -> 068336
# 成功处理: hefei_4193.jpg -> 026750
# 成功处理: hefei_4194.jpg -> 087413
# 成功处理: hefei_4195.jpg -> 018325
# 成功处理: hefei_4197.jpg -> 017153
# 成功处理: hefei_4198.jpg -> 059548
# 成功处理: hefei_4199.jpg -> 067684
# 成功处理: hefei_4201.jpg -> 034693
# 成功处理: hefei_4202.jpg -> 059431
# 成功处理: hefei_4203.jpg -> 034121
# 成功处理: hefei_4206.jpg -> 145583
# 成功处理: hefei_4207.jpg -> 084203
# 成功处理: hefei_4209.jpg -> 058875
# 成功处理: hefei_4210.jpg -> 060026
# 成功处理: hefei_4211.jpg -> 023888
# 成功处理: hefei_4213.jpg -> 077858
# 成功处理: hefei_4214.jpg -> 001633
# 成功处理: hefei_4215.jpg -> 086138
# 成功处理: hefei_4217.jpg -> 029795
# 成功处理: hefei_4218.jpg -> 151281
# 成功处理: hefei_4219.jpg -> 040571
# 成功处理: hefei_4221.jpg -> 035705
# 成功处理: hefei_4222.jpg -> 023708
# 成功处理: hefei_4223.jpg -> 022467
# 成功处理: hefei_4225.jpg -> 030780
# 成功处理: hefei_4226.jpg -> 042150
# 成功处理: hefei_4227.jpg -> 060434
# 成功处理: hefei_4230.jpg -> 073890
# 成功处理: hefei_4231.jpg -> 098964
# 成功处理: hefei_4233.jpg -> 068066
# 成功处理: hefei_4234.jpg -> 058922
# 成功处理: hefei_4237.jpg -> 101895
# 成功处理: hefei_4238.jpg -> 142301
# 成功处理: hefei_4241.jpg -> 068458
# 成功处理: hefei_4242.jpg -> 016978
# 成功处理: hefei_4245.jpg -> 060526
# 成功处理: hefei_4251.jpg -> 020851
# 成功处理: hefei_4255.jpg -> 071846
# 成功处理: hefei_4256.jpg -> 043175
# 成功处理: hefei_4258.jpg -> 018000
# 成功处理: hefei_4260.jpg -> 141211
# 成功处理: hefei_4262.jpg -> 106130
# 成功处理: hefei_4263.jpg -> 068285
# 成功处理: hefei_4266.jpg -> 110689
# 成功处理: hefei_4267.jpg -> 064433
# 成功处理: hefei_4270.jpg -> 018582
# 成功处理: hefei_4271.jpg -> 147467
# 成功处理: hefei_4274.jpg -> 026185
# 成功处理: hefei_4275.jpg -> 185937
# 成功处理: hefei_4276.jpg -> 084693
# 成功处理: hefei_4279.jpg -> 037398
# 成功处理: hefei_4280.jpg -> 066886
# 成功处理: hefei_4282.jpg -> 064920
# 成功处理: hefei_4283.jpg -> 000003
# 成功处理: hefei_4284.jpg -> 031068
# 成功处理: hefei_4286.jpg -> 045192
# 成功处理: hefei_4287.jpg -> 025708
# 成功处理: hefei_4288.jpg -> 055529
# 成功处理: hefei_4290.jpg -> 094278
# 成功处理: hefei_4291.jpg -> 035022
# 成功处理: hefei_4292.jpg -> 071195
# 成功处理: hefei_4294.jpg -> 062183
# 成功处理: hefei_4299.jpg -> 044683
# 成功处理: hefei_4302.jpg -> 069050
# 成功处理: hefei_4304.jpg -> 032353
# 成功处理: hefei_4306.jpg -> 025708
# 成功处理: hefei_4310.jpg -> 028462
# 成功处理: hefei_4311.jpg -> 039537
# 成功处理: hefei_4312.jpg -> 042116
# 成功处理: hefei_4314.jpg -> 026278
# 成功处理: hefei_4315.jpg -> 037000
# 成功处理: hefei_4316.jpg -> 096410
# 成功处理: hefei_4318.jpg -> 041167
# 成功处理: hefei_4324.jpg -> 068540
# 成功处理: hefei_4328.jpg -> 062856
# 成功处理: hefei_4330.jpg -> 064283
# 成功处理: hefei_4332.jpg -> 028071
# 成功处理: hefei_4335.jpg -> 110650
# 成功处理: hefei_4338.jpg -> 068962
# 成功处理: hefei_4340.jpg -> 061482
# 成功处理: hefei_4342.jpg -> 034616
# 成功处理: hefei_4343.jpg -> 051353
# 成功处理: hefei_4344.jpg -> 033426
# 成功处理: hefei_4346.jpg -> 056221
# 成功处理: hefei_4347.jpg -> 030745
# 成功处理: hefei_4350.jpg -> 384932
# 成功处理: hefei_4351.jpg -> 032772
# 成功处理: hefei_4352.jpg -> 098325
# 成功处理: hefei_4354.jpg -> 012745
# 成功处理: hefei_4355.jpg -> 032030
# 成功处理: hefei_4359.jpg -> 031977
# 成功处理: hefei_4360.jpg -> 015308
# 成功处理: hefei_4362.jpg -> 022909
# 成功处理: hefei_4363.jpg -> 103351
# 成功处理: hefei_4366.jpg -> 108761
# 成功处理: hefei_4367.jpg -> 101395
# 成功处理: hefei_4368.jpg -> 046498
# 成功处理: hefei_4372.jpg -> 024072
# 成功处理: hefei_4374.jpg -> 030618
# 成功处理: hefei_4375.jpg -> 015208
# 成功处理: hefei_4378.jpg -> 016410
# 成功处理: hefei_4380.jpg -> 063808
# 成功处理: hefei_4382.jpg -> 296594
# 成功处理: hefei_4383.jpg -> 084225
# 成功处理: hefei_4384.jpg -> 032343
# 成功处理: hefei_4386.jpg -> 074463
# 成功处理: hefei_4387.jpg -> 067083
# 成功处理: hefei_4390.jpg -> 109427
# 成功处理: hefei_4391.jpg -> 029617
# 成功处理: hefei_4394.jpg -> 148523
# 成功处理: hefei_4395.jpg -> 023811
# 成功处理: hefei_4396.jpg -> 054575
# 成功处理: hefei_4398.jpg -> 032824
# 成功处理: hefei_4399.jpg -> 026462
# 成功处理: hefei_4400.jpg -> 025516
# 成功处理: hefei_4403.jpg -> 024253
# 成功处理: hefei_4404.jpg -> 045952
# 成功处理: hefei_4408.jpg -> 383162
# 成功处理: hefei_4413.jpg -> 017047
# 成功处理: hefei_4415.jpg -> 077406
# 成功处理: hefei_4416.jpg -> 058926
# 成功处理: hefei_4419.jpg -> 016845
# 成功处理: hefei_4420.jpg -> 059881
# 成功处理: hefei_4423.jpg -> 077939
# 成功处理: hefei_4427.jpg -> 025163
# 成功处理: hefei_4429.jpg -> 076021
# 成功处理: hefei_4431.jpg -> 102080
# 成功处理: hefei_4432.jpg -> 040111
# 成功处理: hefei_4433.jpg -> 064298
# 成功处理: hefei_4435.jpg -> 016216
# 成功处理: hefei_4437.jpg -> 058128
# 成功处理: hefei_4440.jpg -> 065926
# 成功处理: hefei_4441.jpg -> 031551
# 成功处理: hefei_4447.jpg -> 060229
# 成功处理: hefei_4451.jpg -> 033649
# 成功处理: hefei_4452.jpg -> 021702
# 成功处理: hefei_4453.jpg -> 139400
# 成功处理: hefei_4455.jpg -> 019125
# 成功处理: hefei_4457.jpg -> 074903
# 成功处理: hefei_4459.jpg -> 036840
# 成功处理: hefei_4464.jpg -> 014766
# 成功处理: hefei_4465.jpg -> 033984
# 成功处理: hefei_4468.jpg -> 031108
# 成功处理: hefei_4469.jpg -> 077462
# 成功处理: hefei_4471.jpg -> 083530
# 成功处理: hefei_4472.jpg -> 036473
# 成功处理: hefei_4473.jpg -> 021795
# 成功处理: hefei_4475.jpg -> 035545
# 成功处理: hefei_4476.jpg -> 067613
# 成功处理: hefei_4477.jpg -> 028524
# 成功处理: hefei_4479.jpg -> 061091
# 成功处理: hefei_4483.jpg -> 029932
# 成功处理: hefei_4484.jpg -> 022042
# 成功处理: hefei_4485.jpg -> 029455
# 成功处理: hefei_4488.jpg -> 166858
# 成功处理: hefei_4489.jpg -> 028212
# 成功处理: hefei_4491.jpg -> 038956
# 成功处理: hefei_4492.jpg -> 043237
# 成功处理: hefei_4493.jpg -> 051724
# 成功处理: hefei_4495.jpg -> 034022
# 成功处理: hefei_4496.jpg -> 024071
# 成功处理: hefei_4497.jpg -> 026817
# 成功处理: hefei_4501.jpg -> 033485
# 成功处理: hefei_4503.jpg -> 066931
# 成功处理: hefei_4504.jpg -> 030869
# 成功处理: hefei_4505.jpg -> 038988
# 成功处理: hefei_4508.jpg -> 206180
# 成功处理: hefei_4509.jpg -> 076300
# 成功处理: hefei_4513.jpg -> 294021
# 成功处理: hefei_4515.jpg -> 032307
# 成功处理: hefei_4516.jpg -> 029613
# 成功处理: hefei_4524.jpg -> 042191
# 成功处理: hefei_4528.jpg -> 040444
# 成功处理: hefei_4529.jpg -> 053678
# 处理完成，共处理839张图像

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
import pandas as pd
import numpy as np
from PIL import Image

# 定义数据集类
class MeterDigitDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_files = sorted([f for f in os.listdir(root_dir) if f.endswith('.jpg')])
        
    def __len__(self):
        return len(self.image_files)
    
    def __getitem__(self, idx):
        img_path = os.path.join(self.root_dir, self.image_files[idx])
        image = Image.open(img_path).convert('RGB')
        
        # 从文件名提取真实标签（例如：hefei_3188_0_9.jpg 中的 9）
        parts = self.image_files[idx].split('_')
        true_digit = int(parts[-1].split('.')[0])
        
        if self.transform:
            image = self.transform(image)
            
        return image, true_digit, self.image_files[idx]

# %%
import torch
import torch.nn as nn
import torchvision.models as models

class SEModule(nn.Module):
    """通道注意力机制(Squeeze-and-Excitation)"""
    def __init__(self, channels, reduction=16):
        super(SEModule, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channels, channels // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channels // reduction, channels, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y.expand_as(x)

class ResidualBlock(nn.Module):
    """简单残差块"""
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, 
                              stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, 
                              stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)
        
        # 确保残差连接的维度匹配
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, 
                         stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        residual = x
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(residual)
        out = self.relu(out)
        return out

class AlexNetEnhanced(nn.Module):
    """增强版AlexNet，添加残差连接和注意力机制"""
    def __init__(self, num_classes=10, se_reduction=16, dropout_rate=0.5):
        super(AlexNetEnhanced, self).__init__()
        self.alexnet = models.alexnet(pretrained=True)
        
        # 冻结前10层参数（原始AlexNet共13层特征层，前10层对应前两组卷积）
        for param in list(self.alexnet.parameters())[:10]:  
            param.requires_grad = False
        
        # 提取原始特征层（共13层：0-12）
        original_features = list(self.alexnet.features)
        
        # ---------------------- 特征层分组优化 ----------------------
        # 第1组：输入3→64通道，输出尺寸: (64, 55, 55)
        group1 = original_features[:3]  # Conv2d + ReLU + MaxPool2d(kernel_size=3, stride=2)
        
        # 第2组：64→192通道，输出尺寸: (192, 27, 27)
        group2 = original_features[3:6]  # Conv2d + ReLU + MaxPool2d(kernel_size=3, stride=2)
        
        # 第3组：192→384通道，输出尺寸: (384, 13, 13)
        group3 = original_features[6:8]  # Conv2d + ReLU（原模型此处为两层Conv2d，需调整）
        
        # 第4组：384→256通道，输出尺寸: (256, 13, 13)
        group4 = original_features[8:10]  # Conv2d + ReLU
        
        # 第5组：256→256通道，输出尺寸: (256, 6, 6)
        group5 = original_features[10:13]  # Conv2d + ReLU + MaxPool2d(kernel_size=3, stride=2)
        
        # ---------------------- 添加增强模块 ----------------------
        enhanced_features = (
            group1 + 
            group2 + 
            [ResidualBlock(192, 192), SEModule(192, reduction=se_reduction)] +  # 第2组后添加
            group3 + 
            [ResidualBlock(384, 384), SEModule(384, reduction=se_reduction)] +  # 第3组后添加
            group4 + 
            [ResidualBlock(256, 256), SEModule(256, reduction=se_reduction)] +  # 第4组后添加
            group5
        )
        
        # 组合特征层
        self.alexnet.features = nn.Sequential(*enhanced_features)
        
        # ---------------------- 分类器优化 ----------------------
        self.alexnet.classifier = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(256 * 6 * 6, 2048),  # 减少全连接层参数
            nn.BatchNorm1d(2048),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),
            nn.Linear(2048, num_classes)
        )
    
    def forward(self, x):
        # 调试时可取消注释，打印各层特征图尺寸
        # print("输入尺寸:", x.shape)
        # for layer in self.alexnet.features:
        #     x = layer(x)
        #     print(f"层输出尺寸:", x.shape)
        x = self.alexnet.features(x)
        x = torch.flatten(x, 1)
        x = self.alexnet.classifier(x)
        return x

# %%
def train_model(model, dataloader, criterion, optimizer, num_epochs=10, save_dir='checkpoints'):
    """训练模型并定期保存检查点"""
    os.makedirs(save_dir, exist_ok=True)  # 创建保存目录
    
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    best_acc = 0.0
    
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        
        for inputs, labels, _ in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
        
        epoch_loss = running_loss / len(dataloader)
        epoch_acc = 100. * correct / total
        print(f'Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}, Acc: {epoch_acc:.2f}%')
        
        # 保存当前检查点
        checkpoint_path = os.path.join(save_dir, f'checkpoint_epoch_{epoch+1}.pth')
        torch.save({
            'epoch': epoch+1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': epoch_loss,
            'accuracy': epoch_acc
        }, checkpoint_path)
        
        # 保存最佳模型
        if epoch_acc > best_acc:
            best_acc = epoch_acc
            best_model_path = os.path.join(save_dir, 'best_model.pth')
            torch.save(model.state_dict(), best_model_path)
            print(f'Best model saved with accuracy: {best_acc:.2f}%')
    
    # 保存最终模型
    final_model_path = os.path.join(save_dir, 'final_model.pth')
    torch.save(model.state_dict(), final_model_path)
    print(f'Final model saved at: {final_model_path}')
    
    return model

# %%
# 评估模型并保存详细结果
def evaluate_and_save_results(model, dataloader, data_root='train'):
    output_csv=f'{data_root}/digital_cut.csv'
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()
    
    results = []
    
    with torch.no_grad():
        for inputs, true_digits, filenames in dataloader:
            inputs, true_digits = inputs.to(device), true_digits.to(device)
            outputs = model(inputs)
            _, predicted_digits = outputs.max(1)
            
            # 保存每个数字的预测结果和真实标签
            for filename, pred, true in zip(filenames, predicted_digits, true_digits):
                results.append({
                    'filename': filename,
                    '预测': int(pred),
                    '实际': int(true)
                })
    
    # 保存到CSV
    df = pd.DataFrame(results)
    df.to_csv(output_csv, index=False)
    print(f"数字识别详细结果已保存到 {output_csv}")
    
    return results

# %%
# 从详细结果文件拼接完整电表读数
def combine_digits_from_csv(data_root='train'):
    # 读取详细结果
    input_csv=f'{data_root}/digital_cut.csv'
    output_csv=f'{data_root}/digital_compair.csv'
    df = pd.read_csv(input_csv)
    
    # 创建结果列表
    combined_results = []
    
    # 按基础文件名分组（例如：hefei_3188）
    for base_name, group in df.groupby(lambda x: '_'.join(df.iloc[x]['filename'].split('_')[:2])):
        # 确保有6个数字
        if len(group) != 6:
            print(f"警告: {base_name} 的数字数量不是6个，跳过")
            continue
        
        # 按数字位置排序（索引0-5）
        group = group.sort_values(by='filename', key=lambda x: x.str.split('_').str[-2].astype(int))
        
        # 提取预测数字
        predicted_digits = group['预测'].tolist()
        
        # 计算最终值（从右到左，每个位置乘以对应权重）
        weights = [0.1, 1, 10, 100, 1000, 10000]  # 对应索引0-5的权重
        final_value = sum(d * w for d, w in zip(predicted_digits, weights))
        
        # 构建原始文件名（例如：hefei_3188.jpg）
        original_filename = base_name + '.jpg'
        
        # 添加到结果
        combined_results.append({
            'filename': original_filename,
            'num': final_value
        })
    
    # 保存拼接结果
    result_df = pd.DataFrame(combined_results)
    result_df.to_csv(output_csv, index=False)
    print(f"拼接后的电表读数已保存到 {output_csv}")
    
    return combined_results

# %%
def train_auto(data_root='train', save_dir='models'):
    """主训练函数，添加模型保存目录参数"""
    # 创建主保存目录
    os.makedirs(save_dir, exist_ok=True)
    
    # 数据预处理
    train_dir = f'{data_root}/cut_num'
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    
    # 加载数据集
    dataset = MeterDigitDataset(root_dir=train_dir, transform=transform)
    dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
    
    # 初始化模型
    model = AlexNetEnhanced(num_classes=10)
    
    # 定义损失函数和优化器
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    
    # 创建特定于此次训练的子目录
    import datetime
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    training_save_dir = os.path.join(save_dir, f'training_{timestamp}')
    os.makedirs(training_save_dir, exist_ok=True)
    
    # 训练模型并保存检查点
    print(f"开始训练模型，保存路径: {training_save_dir}")
    model = train_model(model, dataloader, criterion, optimizer, 
                        num_epochs=10, save_dir=training_save_dir)
    
    # 评估模型并保存详细结果（修改保存路径）
    print("评估模型并计算正确率...")
    results = evaluate_and_save_results(model, dataloader, data_root=training_save_dir)
    
    # 计算整体正确率
    if results:
        total_predictions = len(results)
        correct_predictions = sum(1 for item in results if item['预测'] == item['实际'])
        accuracy = (correct_predictions / total_predictions) * 100
        print(f"\n模型整体正确率: {accuracy:.2f}%")
    
    # 从详细结果拼接完整电表读数
    print("拼接完整电表读数...")
    combine_digits_from_csv()
    
    return model, training_save_dir  # 返回模型和保存路径

# %%
combine_digits_from_csv()
# Out:
# 拼接后的电表读数已保存到 train/digital_compair.csv
# [{'filename': 'hefei_3188.jpg.jpg', 'num': 9575.9},
#  {'filename': 'hefei_3190.jpg.jpg', 'num': 19652.0},
#  {'filename': 'hefei_3191.jpg.jpg', 'num': 2262.7},
#  {'filename': 'hefei_3192.jpg.jpg', 'num': 5702.0},
#  {'filename': 'hefei_3194.jpg.jpg', 'num': 2566.0},
#  {'filename': 'hefei_3195.jpg.jpg', 'num': 7509.7},
#  {'filename': 'hefei_3196.jpg.jpg', 'num': 272.3},
#  {'filename': 'hefei_3198.jpg.jpg', 'num': 18304.5},
#  {'filename': 'hefei_3199.jpg.jpg', 'num': 7903.2},
#  {'filename': 'hefei_3200.jpg.jpg', 'num': 5981.5},
#  {'filename': 'hefei_3203.jpg.jpg', 'num': 1921.0},
#  {'filename': 'hefei_3204.jpg.jpg', 'num': 6763.5},
#  {'filename': 'hefei_3205.jpg.jpg', 'num': 12545.8},
#  {'filename': 'hefei_3208.jpg.jpg', 'num': 5598.5},
#  {'filename': 'hefei_3209.jpg.jpg', 'num': 5546.1},
#  {'filename': 'hefei_3210.jpg.jpg', 'num': 6402.1},
#  {'filename': 'hefei_3212.jpg.jpg', 'num': 3467.4},
#  {'filename': 'hefei_3213.jpg.jpg', 'num': 82.7},
#  {'filename': 'hefei_3214.jpg.jpg', 'num': 11290.6},
#  {'filename': 'hefei_3216.jpg.jpg', 'num': 3184.9},
#  {'filename': 'hefei_3217.jpg.jpg', 'num': 6325.9},
#  {'filename': 'hefei_3218.jpg.jpg', 'num': 9041.2},
#  {'filename': 'hefei_3220.jpg.jpg', 'num': 10293.4},
#  {'filename': 'hefei_3221.jpg.jpg', 'num': 4115.3},
#  {'filename': 'hefei_3222.jpg.jpg', 'num': 3673.1},
#  {'filename': 'hefei_3224.jpg.jpg', 'num': 34897.6},
#  {'filename': 'hefei_3225.jpg.jpg', 'num': 12040.2},
#  {'filename': 'hefei_3226.jpg.jpg', 'num': 208.4},
#  {'filename': 'hefei_3228.jpg.jpg', 'num': 10720.4},
#  {'filename': 'hefei_3229.jpg.jpg', 'num': 3073.9},
#  {'filename': 'hefei_3230.jpg.jpg', 'num': 12615.2},
#  {'filename': 'hefei_3232.jpg.jpg', 'num': 5030.2},
#  {'filename': 'hefei_3233.jpg.jpg', 'num': 3158.3},
#  {'filename': 'hefei_3236.jpg.jpg', 'num': 3902.5},
#  {'filename': 'hefei_3237.jpg.jpg', 'num': 13346.2},
#  {'filename': 'hefei_3238.jpg.jpg', 'num': 13486.6},
#  {'filename': 'hefei_3240.jpg.jpg', 'num': 4820.0},
#  {'filename': 'hefei_3241.jpg.jpg', 'num': 2041.1},
#  {'filename': 'hefei_3242.jpg.jpg', 'num': 6396.3},
#  {'filename': 'hefei_3244.jpg.jpg', 'num': 10815.5},
#  {'filename': 'hefei_3245.jpg.jpg', 'num': 3410.4},
#  {'filename': 'hefei_3246.jpg.jpg', 'num': 2782.1},
#  {'filename': 'hefei_3248.jpg.jpg', 'num': 4448.4},
#  {'filename': 'hefei_3249.jpg.jpg', 'num': 3149.6},
#  {'filename': 'hefei_3250.jpg.jpg', 'num': 7151.0},
#  {'filename': 'hefei_3252.jpg.jpg', 'num': 3497.6},
#  {'filename': 'hefei_3253.jpg.jpg', 'num': 7614.4},
#  {'filename': 'hefei_3254.jpg.jpg', 'num': 11000.6},
#  {'filename': 'hefei_3256.jpg.jpg', 'num': 2333.9},
#  {'filename': 'hefei_3257.jpg.jpg', 'num': 11496.3},
#  {'filename': 'hefei_3258.jpg.jpg', 'num': 12991.8},
#  {'filename': 'hefei_3260.jpg.jpg', 'num': 8610.6},
#  {'filename': 'hefei_3261.jpg.jpg', 'num': 1057.0},
#  {'filename': 'hefei_3262.jpg.jpg', 'num': 7227.9},
#  {'filename': 'hefei_3264.jpg.jpg', 'num': 9591.9},
#  {'filename': 'hefei_3265.jpg.jpg', 'num': 6075.8},
#  {'filename': 'hefei_3266.jpg.jpg', 'num': 12045.9},
#  {'filename': 'hefei_3268.jpg.jpg', 'num': 11168.9},
#  {'filename': 'hefei_3269.jpg.jpg', 'num': 3631.9},
#  {'filename': 'hefei_3270.jpg.jpg', 'num': 8454.4},
#  {'filename': 'hefei_3272.jpg.jpg', 'num': 5959.9},
#  {'filename': 'hefei_3273.jpg.jpg', 'num': 974.9},
#  {'filename': 'hefei_3274.jpg.jpg', 'num': 6320.5},
#  {'filename': 'hefei_3276.jpg.jpg', 'num': 7315.9},
#  {'filename': 'hefei_3277.jpg.jpg', 'num': 12845.8},
#  {'filename': 'hefei_3278.jpg.jpg', 'num': 6111.4},
#  {'filename': 'hefei_3280.jpg.jpg', 'num': 3219.0},
#  {'filename': 'hefei_3281.jpg.jpg', 'num': 18881.8},
#  {'filename': 'hefei_3282.jpg.jpg', 'num': 4307.6},
#  {'filename': 'hefei_3284.jpg.jpg', 'num': 12301.1},
#  {'filename': 'hefei_3285.jpg.jpg', 'num': 6754.9},
#  {'filename': 'hefei_3288.jpg.jpg', 'num': 7748.6},
#  {'filename': 'hefei_3289.jpg.jpg', 'num': 11514.6},
#  {'filename': 'hefei_3290.jpg.jpg', 'num': 5073.2},
#  {'filename': 'hefei_3292.jpg.jpg', 'num': 4849.9},
#  {'filename': 'hefei_3293.jpg.jpg', 'num': 1840.1},
#  {'filename': 'hefei_3294.jpg.jpg', 'num': 9908.3},
#  {'filename': 'hefei_3296.jpg.jpg', 'num': 3795.2},
#  {'filename': 'hefei_3297.jpg.jpg', 'num': 7449.2},
#  {'filename': 'hefei_3298.jpg.jpg', 'num': 32138.6},
#  {'filename': 'hefei_3300.jpg.jpg', 'num': 10013.8},
#  {'filename': 'hefei_3301.jpg.jpg', 'num': 10914.7},
#  {'filename': 'hefei_3302.jpg.jpg', 'num': 7470.5},
#  {'filename': 'hefei_3304.jpg.jpg', 'num': 1143.8},
#  {'filename': 'hefei_3305.jpg.jpg', 'num': 6847.8},
#  {'filename': 'hefei_3306.jpg.jpg', 'num': 6685.6},
#  {'filename': 'hefei_3308.jpg.jpg', 'num': 9891.3},
#  {'filename': 'hefei_3309.jpg.jpg', 'num': 2350.8},
#  {'filename': 'hefei_3310.jpg.jpg', 'num': 6787.7},
#  {'filename': 'hefei_3312.jpg.jpg', 'num': 9694.0},
#  {'filename': 'hefei_3313.jpg.jpg', 'num': 9949.7},
#  {'filename': 'hefei_3314.jpg.jpg', 'num': 2863.3},
#  {'filename': 'hefei_3316.jpg.jpg', 'num': 7166.3},
#  {'filename': 'hefei_3317.jpg.jpg', 'num': 21974.3},
#  {'filename': 'hefei_3318.jpg.jpg', 'num': 9537.5},
#  {'filename': 'hefei_3320.jpg.jpg', 'num': 15001.7},
#  {'filename': 'hefei_3321.jpg.jpg', 'num': 3156.5},
#  {'filename': 'hefei_3322.jpg.jpg', 'num': 14816.5},
#  {'filename': 'hefei_3324.jpg.jpg', 'num': 2378.8},
#  {'filename': 'hefei_3325.jpg.jpg', 'num': 6379.1},
#  {'filename': 'hefei_3326.jpg.jpg', 'num': 3575.3},
#  {'filename': 'hefei_3328.jpg.jpg', 'num': 8412.3},
#  {'filename': 'hefei_3329.jpg.jpg', 'num': 5996.2},
#  {'filename': 'hefei_3330.jpg.jpg', 'num': 5918.5},
#  {'filename': 'hefei_3332.jpg.jpg', 'num': 11968.9},
#  {'filename': 'hefei_3333.jpg.jpg', 'num': 7174.1},
#  {'filename': 'hefei_3334.jpg.jpg', 'num': 7962.9},
#  {'filename': 'hefei_3336.jpg.jpg', 'num': 10131.8},
#  {'filename': 'hefei_3337.jpg.jpg', 'num': 4208.2},
#  {'filename': 'hefei_3338.jpg.jpg', 'num': 10185.4},
#  {'filename': 'hefei_3340.jpg.jpg', 'num': 15114.2},
#  {'filename': 'hefei_3341.jpg.jpg', 'num': 7621.5},
#  {'filename': 'hefei_3342.jpg.jpg', 'num': 5095.3},
#  {'filename': 'hefei_3344.jpg.jpg', 'num': 2726.1},
#  {'filename': 'hefei_3345.jpg.jpg', 'num': 3252.2},
#  {'filename': 'hefei_3346.jpg.jpg', 'num': 9075.4},
#  {'filename': 'hefei_3348.jpg.jpg', 'num': 6165.1},
#  {'filename': 'hefei_3349.jpg.jpg', 'num': 2827.8},
#  {'filename': 'hefei_3350.jpg.jpg', 'num': 3582.0},
#  {'filename': 'hefei_3352.jpg.jpg', 'num': 5276.3},
#  {'filename': 'hefei_3353.jpg.jpg', 'num': 8215.8},
#  {'filename': 'hefei_3354.jpg.jpg', 'num': 19995.5},
#  {'filename': 'hefei_3356.jpg.jpg', 'num': 9137.9},
#  {'filename': 'hefei_3357.jpg.jpg', 'num': 19317.1},
#  {'filename': 'hefei_3358.jpg.jpg', 'num': 10712.2},
#  {'filename': 'hefei_3360.jpg.jpg', 'num': 7478.3},
#  {'filename': 'hefei_3361.jpg.jpg', 'num': 6930.4},
#  {'filename': 'hefei_3362.jpg.jpg', 'num': 6351.3},
#  {'filename': 'hefei_3364.jpg.jpg', 'num': 2184.6},
#  {'filename': 'hefei_3365.jpg.jpg', 'num': 3950.0},
#  {'filename': 'hefei_3366.jpg.jpg', 'num': 5138.0},
#  {'filename': 'hefei_3368.jpg.jpg', 'num': 247.2},
#  {'filename': 'hefei_3369.jpg.jpg', 'num': 6405.8},
#  {'filename': 'hefei_3370.jpg.jpg', 'num': 1327.2},
#  {'filename': 'hefei_3372.jpg.jpg', 'num': 3796.9},
#  {'filename': 'hefei_3373.jpg.jpg', 'num': 10278.2},
#  {'filename': 'hefei_3374.jpg.jpg', 'num': 8144.9},
#  {'filename': 'hefei_3376.jpg.jpg', 'num': 24021.0},
#  {'filename': 'hefei_3377.jpg.jpg', 'num': 1170.3},
#  {'filename': 'hefei_3378.jpg.jpg', 'num': 2653.2},
#  {'filename': 'hefei_3380.jpg.jpg', 'num': 5912.7},
#  {'filename': 'hefei_3381.jpg.jpg', 'num': 2721.9},
#  {'filename': 'hefei_3382.jpg.jpg', 'num': 11540.9},
#  {'filename': 'hefei_3384.jpg.jpg', 'num': 12275.8},
#  {'filename': 'hefei_3385.jpg.jpg', 'num': 15517.7},
#  {'filename': 'hefei_3386.jpg.jpg', 'num': 3184.1},
#  {'filename': 'hefei_3388.jpg.jpg', 'num': 2040.3},
#  {'filename': 'hefei_3389.jpg.jpg', 'num': 0.0},
#  {'filename': 'hefei_3390.jpg.jpg', 'num': 5790.2},
#  {'filename': 'hefei_3393.jpg.jpg', 'num': 4909.8},
#  {'filename': 'hefei_3394.jpg.jpg', 'num': 8707.2},
#  {'filename': 'hefei_3395.jpg.jpg', 'num': 6841.3},
#  {'filename': 'hefei_3397.jpg.jpg', 'num': 7453.6},
#  {'filename': 'hefei_3398.jpg.jpg', 'num': 8568.9},
#  {'filename': 'hefei_3399.jpg.jpg', 'num': 2257.2},
#  {'filename': 'hefei_3401.jpg.jpg', 'num': 7378.6},
#  {'filename': 'hefei_3402.jpg.jpg', 'num': 6794.2},
#  {'filename': 'hefei_3403.jpg.jpg', 'num': 6065.0},
#  {'filename': 'hefei_3406.jpg.jpg', 'num': 7748.7},
#  {'filename': 'hefei_3407.jpg.jpg', 'num': 7517.4},
#  {'filename': 'hefei_3408.jpg.jpg', 'num': 7467.1},
#  {'filename': 'hefei_3410.jpg.jpg', 'num': 2125.3},
#  {'filename': 'hefei_3411.jpg.jpg', 'num': 2432.6},
#  {'filename': 'hefei_3412.jpg.jpg', 'num': 9858.3},
#  {'filename': 'hefei_3414.jpg.jpg', 'num': 6107.3},
#  {'filename': 'hefei_3415.jpg.jpg', 'num': 2085.6},
#  {'filename': 'hefei_3416.jpg.jpg', 'num': 10311.2},
#  {'filename': 'hefei_3418.jpg.jpg', 'num': 21591.3},
#  {'filename': 'hefei_3419.jpg.jpg', 'num': 9693.3},
#  {'filename': 'hefei_3420.jpg.jpg', 'num': 7687.4},
#  {'filename': 'hefei_3422.jpg.jpg', 'num': 7158.5},
#  {'filename': 'hefei_3423.jpg.jpg', 'num': 8078.2},
#  {'filename': 'hefei_3424.jpg.jpg', 'num': 8687.5},
#  {'filename': 'hefei_3426.jpg.jpg', 'num': 20412.3},
#  {'filename': 'hefei_3427.jpg.jpg', 'num': 5999.5},
#  {'filename': 'hefei_3428.jpg.jpg', 'num': 2115.6},
#  {'filename': 'hefei_3430.jpg.jpg', 'num': 120.6},
#  {'filename': 'hefei_3431.jpg.jpg', 'num': 12110.9},
#  {'filename': 'hefei_3432.jpg.jpg', 'num': 8615.6},
#  {'filename': 'hefei_3434.jpg.jpg', 'num': 6065.1},
#  {'filename': 'hefei_3435.jpg.jpg', 'num': 3256.0},
#  {'filename': 'hefei_3436.jpg.jpg', 'num': 7389.9},
#  {'filename': 'hefei_3438.jpg.jpg', 'num': 782.4},
#  {'filename': 'hefei_3439.jpg.jpg', 'num': 1092.8},
#  {'filename': 'hefei_3440.jpg.jpg', 'num': 12289.9},
#  {'filename': 'hefei_3442.jpg.jpg', 'num': 2395.4},
#  {'filename': 'hefei_3443.jpg.jpg', 'num': 8123.3},
#  {'filename': 'hefei_3444.jpg.jpg', 'num': 2493.6},
#  {'filename': 'hefei_3446.jpg.jpg', 'num': 8669.8},
#  {'filename': 'hefei_3447.jpg.jpg', 'num': 6104.2},
#  {'filename': 'hefei_3448.jpg.jpg', 'num': 3459.9},
#  {'filename': 'hefei_3450.jpg.jpg', 'num': 12234.7},
#  {'filename': 'hefei_3451.jpg.jpg', 'num': 3471.5},
#  {'filename': 'hefei_3452.jpg.jpg', 'num': 11726.2},
#  {'filename': 'hefei_3454.jpg.jpg', 'num': 18233.9},
#  {'filename': 'hefei_3455.jpg.jpg', 'num': 2606.7},
#  {'filename': 'hefei_3456.jpg.jpg', 'num': 6587.8},
#  {'filename': 'hefei_3458.jpg.jpg', 'num': 5784.4},
#  {'filename': 'hefei_3459.jpg.jpg', 'num': 11970.2},
#  {'filename': 'hefei_3460.jpg.jpg', 'num': 5748.9},
#  {'filename': 'hefei_3462.jpg.jpg', 'num': 2289.4},
#  {'filename': 'hefei_3463.jpg.jpg', 'num': 2200.1},
#  {'filename': 'hefei_3464.jpg.jpg', 'num': 7694.7},
#  {'filename': 'hefei_3466.jpg.jpg', 'num': 3410.6},
#  {'filename': 'hefei_3467.jpg.jpg', 'num': 2058.8},
#  {'filename': 'hefei_3468.jpg.jpg', 'num': 8853.7},
#  {'filename': 'hefei_3470.jpg.jpg', 'num': 8267.2},
#  {'filename': 'hefei_3471.jpg.jpg', 'num': 2063.6},
#  {'filename': 'hefei_3472.jpg.jpg', 'num': 1976.1},
#  {'filename': 'hefei_3474.jpg.jpg', 'num': 3970.9},
#  {'filename': 'hefei_3475.jpg.jpg', 'num': 3945.7},
#  {'filename': 'hefei_3476.jpg.jpg', 'num': 10997.5},
#  {'filename': 'hefei_3478.jpg.jpg', 'num': 3215.7},
#  {'filename': 'hefei_3479.jpg.jpg', 'num': 4995.2},
#  {'filename': 'hefei_3480.jpg.jpg', 'num': 7543.5},
#  {'filename': 'hefei_3482.jpg.jpg', 'num': 9529.3},
#  {'filename': 'hefei_3483.jpg.jpg', 'num': 3236.4},
#  {'filename': 'hefei_3484.jpg.jpg', 'num': 1212.2},
#  {'filename': 'hefei_3486.jpg.jpg', 'num': 12439.2},
#  {'filename': 'hefei_3487.jpg.jpg', 'num': 7194.1},
#  {'filename': 'hefei_3488.jpg.jpg', 'num': 2874.4},
#  {'filename': 'hefei_3490.jpg.jpg', 'num': 17161.4},
#  {'filename': 'hefei_3491.jpg.jpg', 'num': 3055.4},
#  {'filename': 'hefei_3492.jpg.jpg', 'num': 2146.8},
#  {'filename': 'hefei_3495.jpg.jpg', 'num': 7532.6},
#  {'filename': 'hefei_3496.jpg.jpg', 'num': 14315.0},
#  {'filename': 'hefei_3497.jpg.jpg', 'num': 6796.6},
#  {'filename': 'hefei_3499.jpg.jpg', 'num': 3828.0},
#  {'filename': 'hefei_3500.jpg.jpg', 'num': 6788.3},
#  {'filename': 'hefei_3501.jpg.jpg', 'num': 18076.3},
#  {'filename': 'hefei_3503.jpg.jpg', 'num': 2083.2},
#  {'filename': 'hefei_3504.jpg.jpg', 'num': 6711.5},
#  {'filename': 'hefei_3505.jpg.jpg', 'num': 5342.2},
#  {'filename': 'hefei_3507.jpg.jpg', 'num': 7453.0},
#  {'filename': 'hefei_3508.jpg.jpg', 'num': 2415.5},
#  {'filename': 'hefei_3509.jpg.jpg', 'num': 6312.0},
#  {'filename': 'hefei_3511.jpg.jpg', 'num': 5091.7},
#  {'filename': 'hefei_3512.jpg.jpg', 'num': 7124.7},
#  {'filename': 'hefei_3513.jpg.jpg', 'num': 6602.3},
#  {'filename': 'hefei_3515.jpg.jpg', 'num': 14325.1},
#  {'filename': 'hefei_3516.jpg.jpg', 'num': 6013.1},
#  {'filename': 'hefei_3517.jpg.jpg', 'num': 4129.9},
#  {'filename': 'hefei_3519.jpg.jpg', 'num': 7223.2},
#  {'filename': 'hefei_3520.jpg.jpg', 'num': 3964.3},
#  {'filename': 'hefei_3521.jpg.jpg', 'num': 2307.5},
#  {'filename': 'hefei_3523.jpg.jpg', 'num': 12431.2},
#  {'filename': 'hefei_3524.jpg.jpg', 'num': 11293.8},
#  {'filename': 'hefei_3525.jpg.jpg', 'num': 7101.9},
#  {'filename': 'hefei_3527.jpg.jpg', 'num': 3311.0},
#  {'filename': 'hefei_3528.jpg.jpg', 'num': 6949.7},
#  {'filename': 'hefei_3529.jpg.jpg', 'num': 2640.5},
#  {'filename': 'hefei_3531.jpg.jpg', 'num': 731.3},
#  {'filename': 'hefei_3532.jpg.jpg', 'num': 16123.4},
#  {'filename': 'hefei_3533.jpg.jpg', 'num': 12343.1},
#  {'filename': 'hefei_3535.jpg.jpg', 'num': 12384.3},
#  {'filename': 'hefei_3536.jpg.jpg', 'num': 6145.1},
#  {'filename': 'hefei_3537.jpg.jpg', 'num': 3578.3},
#  {'filename': 'hefei_3539.jpg.jpg', 'num': 13993.5},
#  {'filename': 'hefei_3540.jpg.jpg', 'num': 11111.3},
#  {'filename': 'hefei_3541.jpg.jpg', 'num': 4537.2},
#  {'filename': 'hefei_3543.jpg.jpg', 'num': 6933.7},
#  {'filename': 'hefei_3544.jpg.jpg', 'num': 2993.7},
#  {'filename': 'hefei_3545.jpg.jpg', 'num': 3358.2},
#  {'filename': 'hefei_3547.jpg.jpg', 'num': 5802.9},
#  {'filename': 'hefei_3548.jpg.jpg', 'num': 5474.6},
#  {'filename': 'hefei_3549.jpg.jpg', 'num': 680.8},
#  {'filename': 'hefei_3551.jpg.jpg', 'num': 12951.3},
#  {'filename': 'hefei_3552.jpg.jpg', 'num': 6195.6},
#  {'filename': 'hefei_3553.jpg.jpg', 'num': 6856.4},
#  {'filename': 'hefei_3555.jpg.jpg', 'num': 2111.4},
#  {'filename': 'hefei_3556.jpg.jpg', 'num': 2921.5},
#  {'filename': 'hefei_3557.jpg.jpg', 'num': 3452.1},
#  {'filename': 'hefei_3559.jpg.jpg', 'num': 11446.9},
#  {'filename': 'hefei_3560.jpg.jpg', 'num': 17642.1},
#  {'filename': 'hefei_3561.jpg.jpg', 'num': 24398.8},
#  {'filename': 'hefei_3563.jpg.jpg', 'num': 13725.4},
#  {'filename': 'hefei_3564.jpg.jpg', 'num': 3571.4},
#  {'filename': 'hefei_3565.jpg.jpg', 'num': 8278.8},
#  {'filename': 'hefei_3567.jpg.jpg', 'num': 6114.8},
#  {'filename': 'hefei_3568.jpg.jpg', 'num': 2472.8},
#  {'filename': 'hefei_3569.jpg.jpg', 'num': 7195.0},
#  {'filename': 'hefei_3571.jpg.jpg', 'num': 23964.3},
#  {'filename': 'hefei_3572.jpg.jpg', 'num': 703.9},
#  {'filename': 'hefei_3573.jpg.jpg', 'num': 961.5},
#  {'filename': 'hefei_3575.jpg.jpg', 'num': 8494.7},
#  {'filename': 'hefei_3576.jpg.jpg', 'num': 14572.8},
#  {'filename': 'hefei_3577.jpg.jpg', 'num': 808.5},
#  {'filename': 'hefei_3579.jpg.jpg', 'num': 13888.7},
#  {'filename': 'hefei_3580.jpg.jpg', 'num': 12067.2},
#  {'filename': 'hefei_3581.jpg.jpg', 'num': 6287.3},
#  {'filename': 'hefei_3583.jpg.jpg', 'num': 13807.6},
#  {'filename': 'hefei_3584.jpg.jpg', 'num': 8708.2},
#  {'filename': 'hefei_3585.jpg.jpg', 'num': 4419.9},
#  {'filename': 'hefei_3587.jpg.jpg', 'num': 15112.5},
#  {'filename': 'hefei_3588.jpg.jpg', 'num': 2626.7},
#  {'filename': 'hefei_3589.jpg.jpg', 'num': 7426.6},
#  {'filename': 'hefei_3591.jpg.jpg', 'num': 6441.6},
#  {'filename': 'hefei_3592.jpg.jpg', 'num': 15072.8},
#  {'filename': 'hefei_3593.jpg.jpg', 'num': 2957.6},
#  {'filename': 'hefei_3595.jpg.jpg', 'num': 4973.8},
#  {'filename': 'hefei_3596.jpg.jpg', 'num': 2160.8},
#  {'filename': 'hefei_3597.jpg.jpg', 'num': 11668.6},
#  {'filename': 'hefei_3599.jpg.jpg', 'num': 50096.9},
#  {'filename': 'hefei_3600.jpg.jpg', 'num': 2116.3},
#  {'filename': 'hefei_3601.jpg.jpg', 'num': 3265.8},
#  {'filename': 'hefei_3603.jpg.jpg', 'num': 8127.8},
#  {'filename': 'hefei_3604.jpg.jpg', 'num': 15237.6},
#  {'filename': 'hefei_3605.jpg.jpg', 'num': 5721.5},
#  {'filename': 'hefei_3607.jpg.jpg', 'num': 3317.4},
#  {'filename': 'hefei_3608.jpg.jpg', 'num': 1813.4},
#  {'filename': 'hefei_3609.jpg.jpg', 'num': 11078.6},
#  {'filename': 'hefei_3612.jpg.jpg', 'num': 7508.0},
#  {'filename': 'hefei_3613.jpg.jpg', 'num': 927.9},
#  {'filename': 'hefei_3615.jpg.jpg', 'num': 17921.0},
#  {'filename': 'hefei_3616.jpg.jpg', 'num': 9232.0},
#  {'filename': 'hefei_3617.jpg.jpg', 'num': 3165.2},
#  {'filename': 'hefei_3619.jpg.jpg', 'num': 6273.1},
#  {'filename': 'hefei_3620.jpg.jpg', 'num': 14093.5},
#  {'filename': 'hefei_3621.jpg.jpg', 'num': 15220.9},
#  {'filename': 'hefei_3623.jpg.jpg', 'num': 8135.3},
#  {'filename': 'hefei_3624.jpg.jpg', 'num': 14290.1},
#  {'filename': 'hefei_3625.jpg.jpg', 'num': 6682.0},
#  {'filename': 'hefei_3627.jpg.jpg', 'num': 9102.5},
#  {'filename': 'hefei_3628.jpg.jpg', 'num': 11576.3},
#  {'filename': 'hefei_3629.jpg.jpg', 'num': 6742.8},
#  {'filename': 'hefei_3631.jpg.jpg', 'num': 6429.8},
#  {'filename': 'hefei_3632.jpg.jpg', 'num': 14197.3},
#  {'filename': 'hefei_3633.jpg.jpg', 'num': 608.4},
#  {'filename': 'hefei_3635.jpg.jpg', 'num': 3646.6},
#  {'filename': 'hefei_3636.jpg.jpg', 'num': 7204.2},
#  {'filename': 'hefei_3637.jpg.jpg', 'num': 0.4},
#  {'filename': 'hefei_3639.jpg.jpg', 'num': 7041.1},
#  {'filename': 'hefei_3640.jpg.jpg', 'num': 14044.6},
#  {'filename': 'hefei_3641.jpg.jpg', 'num': 3567.2},
#  {'filename': 'hefei_3643.jpg.jpg', 'num': 2279.2},
#  {'filename': 'hefei_3644.jpg.jpg', 'num': 2127.8},
#  {'filename': 'hefei_3645.jpg.jpg', 'num': 6971.3},
#  {'filename': 'hefei_3647.jpg.jpg', 'num': 1666.6},
#  {'filename': 'hefei_3648.jpg.jpg', 'num': 7545.4},
#  {'filename': 'hefei_3649.jpg.jpg', 'num': 6856.6},
#  {'filename': 'hefei_3651.jpg.jpg', 'num': 8329.8},
#  {'filename': 'hefei_3652.jpg.jpg', 'num': 3012.2},
#  {'filename': 'hefei_3653.jpg.jpg', 'num': 6167.2},
#  {'filename': 'hefei_3655.jpg.jpg', 'num': 11625.0},
#  {'filename': 'hefei_3656.jpg.jpg', 'num': 2312.4},
#  {'filename': 'hefei_3657.jpg.jpg', 'num': 2598.5},
#  {'filename': 'hefei_3659.jpg.jpg', 'num': 7144.1},
#  {'filename': 'hefei_3660.jpg.jpg', 'num': 3342.4},
#  {'filename': 'hefei_3661.jpg.jpg', 'num': 8667.1},
#  {'filename': 'hefei_3663.jpg.jpg', 'num': 3493.1},
#  {'filename': 'hefei_3664.jpg.jpg', 'num': 939.2},
#  {'filename': 'hefei_3665.jpg.jpg', 'num': 5827.1},
#  {'filename': 'hefei_3667.jpg.jpg', 'num': 2592.7},
#  {'filename': 'hefei_3668.jpg.jpg', 'num': 6230.1},
#  {'filename': 'hefei_3669.jpg.jpg', 'num': 6835.8},
#  {'filename': 'hefei_3671.jpg.jpg', 'num': 5300.8},
#  {'filename': 'hefei_3672.jpg.jpg', 'num': 4846.6},
#  {'filename': 'hefei_3673.jpg.jpg', 'num': 1647.9},
#  {'filename': 'hefei_3675.jpg.jpg', 'num': 10812.8},
#  {'filename': 'hefei_3676.jpg.jpg', 'num': 7450.2},
#  {'filename': 'hefei_3677.jpg.jpg', 'num': 7688.4},
#  {'filename': 'hefei_3679.jpg.jpg', 'num': 3586.1},
#  {'filename': 'hefei_3680.jpg.jpg', 'num': 3229.2},
#  {'filename': 'hefei_3681.jpg.jpg', 'num': 6154.3},
#  {'filename': 'hefei_3683.jpg.jpg', 'num': 12863.3},
#  {'filename': 'hefei_3684.jpg.jpg', 'num': 893.1},
#  {'filename': 'hefei_3685.jpg.jpg', 'num': 6048.1},
#  {'filename': 'hefei_3687.jpg.jpg', 'num': 11728.4},
#  {'filename': 'hefei_3688.jpg.jpg', 'num': 6053.7},
#  {'filename': 'hefei_3689.jpg.jpg', 'num': 8009.9},
#  {'filename': 'hefei_3691.jpg.jpg', 'num': 14617.8},
#  {'filename': 'hefei_3692.jpg.jpg', 'num': 3436.3},
#  {'filename': 'hefei_3693.jpg.jpg', 'num': 12088.3},
#  {'filename': 'hefei_3695.jpg.jpg', 'num': 7995.4},
#  {'filename': 'hefei_3696.jpg.jpg', 'num': 15745.7},
#  {'filename': 'hefei_3697.jpg.jpg', 'num': 4480.1},
#  {'filename': 'hefei_3699.jpg.jpg', 'num': 2858.1},
#  {'filename': 'hefei_3700.jpg.jpg', 'num': 2001.4},
#  {'filename': 'hefei_3701.jpg.jpg', 'num': 5078.5},
#  {'filename': 'hefei_3703.jpg.jpg', 'num': 7161.9},
#  {'filename': 'hefei_3704.jpg.jpg', 'num': 56929.5},
#  {'filename': 'hefei_3705.jpg.jpg', 'num': 6809.1},
#  {'filename': 'hefei_3707.jpg.jpg', 'num': 7026.5},
#  {'filename': 'hefei_3708.jpg.jpg', 'num': 42618.4},
#  {'filename': 'hefei_3709.jpg.jpg', 'num': 3062.6},
#  {'filename': 'hefei_3711.jpg.jpg', 'num': 7099.9},
#  {'filename': 'hefei_3712.jpg.jpg', 'num': 7707.0},
#  {'filename': 'hefei_3713.jpg.jpg', 'num': 6773.9},
#  {'filename': 'hefei_3715.jpg.jpg', 'num': 4085.3},
#  {'filename': 'hefei_3716.jpg.jpg', 'num': 7468.1},
#  {'filename': 'hefei_3717.jpg.jpg', 'num': 19356.3},
#  {'filename': 'hefei_3719.jpg.jpg', 'num': 6764.5},
#  {'filename': 'hefei_3720.jpg.jpg', 'num': 7257.0},
#  {'filename': 'hefei_3721.jpg.jpg', 'num': 3334.1},
#  {'filename': 'hefei_3723.jpg.jpg', 'num': 8793.5},
#  {'filename': 'hefei_3724.jpg.jpg', 'num': 6380.3},
#  {'filename': 'hefei_3725.jpg.jpg', 'num': 5043.4},
#  {'filename': 'hefei_3727.jpg.jpg', 'num': 10068.7},
#  {'filename': 'hefei_3728.jpg.jpg', 'num': 6026.0},
#  {'filename': 'hefei_3729.jpg.jpg', 'num': 14478.7},
#  {'filename': 'hefei_3731.jpg.jpg', 'num': 12278.6},
#  {'filename': 'hefei_3732.jpg.jpg', 'num': 7097.6},
#  {'filename': 'hefei_3733.jpg.jpg', 'num': 11523.0},
#  {'filename': 'hefei_3735.jpg.jpg', 'num': 6138.0},
#  {'filename': 'hefei_3736.jpg.jpg', 'num': 18013.1},
#  {'filename': 'hefei_3737.jpg.jpg', 'num': 701.9},
#  {'filename': 'hefei_3739.jpg.jpg', 'num': 7309.2},
#  {'filename': 'hefei_3740.jpg.jpg', 'num': 7410.5},
#  {'filename': 'hefei_3741.jpg.jpg', 'num': 2513.5},
#  {'filename': 'hefei_3743.jpg.jpg', 'num': 10470.7},
#  {'filename': 'hefei_3744.jpg.jpg', 'num': 9431.3},
#  {'filename': 'hefei_3745.jpg.jpg', 'num': 11569.2},
#  {'filename': 'hefei_3747.jpg.jpg', 'num': 878.5},
#  {'filename': 'hefei_3748.jpg.jpg', 'num': 2030.8},
#  {'filename': 'hefei_3749.jpg.jpg', 'num': 7765.4},
#  {'filename': 'hefei_3751.jpg.jpg', 'num': 6550.5},
#  {'filename': 'hefei_3752.jpg.jpg', 'num': 6207.1},
#  {'filename': 'hefei_3753.jpg.jpg', 'num': 14719.8},
#  {'filename': 'hefei_3755.jpg.jpg', 'num': 7129.9},
#  {'filename': 'hefei_3756.jpg.jpg', 'num': 7367.7},
#  {'filename': 'hefei_3757.jpg.jpg', 'num': 14108.0},
#  {'filename': 'hefei_3759.jpg.jpg', 'num': 4107.8},
#  {'filename': 'hefei_3760.jpg.jpg', 'num': 26199.9},
#  {'filename': 'hefei_3761.jpg.jpg', 'num': 3377.9},
#  {'filename': 'hefei_3763.jpg.jpg', 'num': 15558.7},
#  {'filename': 'hefei_3764.jpg.jpg', 'num': 6455.7},
#  {'filename': 'hefei_3765.jpg.jpg', 'num': 7091.5},
#  {'filename': 'hefei_3767.jpg.jpg', 'num': 17930.2},
#  {'filename': 'hefei_3768.jpg.jpg', 'num': 4567.7},
#  {'filename': 'hefei_3769.jpg.jpg', 'num': 6043.0},
#  {'filename': 'hefei_3771.jpg.jpg', 'num': 3609.7},
#  {'filename': 'hefei_3772.jpg.jpg', 'num': 3888.6},
#  {'filename': 'hefei_3773.jpg.jpg', 'num': 5882.2},
#  {'filename': 'hefei_3775.jpg.jpg', 'num': 9688.0},
#  {'filename': 'hefei_3776.jpg.jpg', 'num': 6093.1},
#  {'filename': 'hefei_3777.jpg.jpg', 'num': 11014.5},
#  {'filename': 'hefei_3779.jpg.jpg', 'num': 13949.9},
#  {'filename': 'hefei_3780.jpg.jpg', 'num': 33412.2},
#  {'filename': 'hefei_3781.jpg.jpg', 'num': 12493.9},
#  {'filename': 'hefei_3783.jpg.jpg', 'num': 6048.7},
#  {'filename': 'hefei_3784.jpg.jpg', 'num': 178.6},
#  {'filename': 'hefei_3785.jpg.jpg', 'num': 14355.8},
#  {'filename': 'hefei_3787.jpg.jpg', 'num': 1552.6},
#  {'filename': 'hefei_3788.jpg.jpg', 'num': 5347.2},
#  {'filename': 'hefei_3789.jpg.jpg', 'num': 2115.6},
#  {'filename': 'hefei_3791.jpg.jpg', 'num': 6868.3},
#  {'filename': 'hefei_3792.jpg.jpg', 'num': 7249.9},
#  {'filename': 'hefei_3793.jpg.jpg', 'num': 6957.0},
#  {'filename': 'hefei_3795.jpg.jpg', 'num': 3877.0},
#  {'filename': 'hefei_3796.jpg.jpg', 'num': 7212.4},
#  {'filename': 'hefei_3797.jpg.jpg', 'num': 9751.1},
#  {'filename': 'hefei_3799.jpg.jpg', 'num': 8249.8},
#  {'filename': 'hefei_3800.jpg.jpg', 'num': 22746.4},
#  {'filename': 'hefei_3801.jpg.jpg', 'num': 2487.6},
#  {'filename': 'hefei_3803.jpg.jpg', 'num': 6647.8},
#  {'filename': 'hefei_3804.jpg.jpg', 'num': 10301.6},
#  {'filename': 'hefei_3805.jpg.jpg', 'num': 11246.4},
#  {'filename': 'hefei_3808.jpg.jpg', 'num': 7490.2},
#  {'filename': 'hefei_3811.jpg.jpg', 'num': 3215.4},
#  {'filename': 'hefei_3812.jpg.jpg', 'num': 7715.5},
#  {'filename': 'hefei_3813.jpg.jpg', 'num': 6226.5},
#  {'filename': 'hefei_3816.jpg.jpg', 'num': 5943.1},
#  {'filename': 'hefei_3817.jpg.jpg', 'num': 2909.9},
#  {'filename': 'hefei_3819.jpg.jpg', 'num': 11626.9},
#  {'filename': 'hefei_3820.jpg.jpg', 'num': 11899.0},
#  {'filename': 'hefei_3821.jpg.jpg', 'num': 6536.9},
#  {'filename': 'hefei_3823.jpg.jpg', 'num': 6727.1},
#  {'filename': 'hefei_3824.jpg.jpg', 'num': 7163.3},
#  {'filename': 'hefei_3827.jpg.jpg', 'num': 8435.6},
#  {'filename': 'hefei_3828.jpg.jpg', 'num': 1817.8},
#  {'filename': 'hefei_3829.jpg.jpg', 'num': 8841.6},
#  {'filename': 'hefei_3831.jpg.jpg', 'num': 5719.8},
#  {'filename': 'hefei_3832.jpg.jpg', 'num': 6668.4},
#  {'filename': 'hefei_3833.jpg.jpg', 'num': 2062.6},
#  {'filename': 'hefei_3836.jpg.jpg', 'num': 4858.2},
#  {'filename': 'hefei_3837.jpg.jpg', 'num': 19032.6},
#  {'filename': 'hefei_3838.jpg.jpg', 'num': 2100.9},
#  {'filename': 'hefei_3840.jpg.jpg', 'num': 9703.7},
#  {'filename': 'hefei_3842.jpg.jpg', 'num': 7006.7},
#  {'filename': 'hefei_3844.jpg.jpg', 'num': 19415.3},
#  {'filename': 'hefei_3845.jpg.jpg', 'num': 13633.3},
#  {'filename': 'hefei_3846.jpg.jpg', 'num': 1971.6},
#  {'filename': 'hefei_3849.jpg.jpg', 'num': 8342.4},
#  {'filename': 'hefei_3850.jpg.jpg', 'num': 15119.1},
#  {'filename': 'hefei_3852.jpg.jpg', 'num': 6748.4},
#  {'filename': 'hefei_3853.jpg.jpg', 'num': 24163.2},
#  {'filename': 'hefei_3854.jpg.jpg', 'num': 6639.7},
#  {'filename': 'hefei_3857.jpg.jpg', 'num': 15849.1},
#  {'filename': 'hefei_3858.jpg.jpg', 'num': 14022.7},
#  {'filename': 'hefei_3860.jpg.jpg', 'num': 10803.4},
#  {'filename': 'hefei_3861.jpg.jpg', 'num': 6756.9},
#  {'filename': 'hefei_3862.jpg.jpg', 'num': 14308.6},
#  {'filename': 'hefei_3865.jpg.jpg', 'num': 2139.9},
#  {'filename': 'hefei_3866.jpg.jpg', 'num': 13836.0},
#  {'filename': 'hefei_3868.jpg.jpg', 'num': 9806.4},
#  {'filename': 'hefei_3869.jpg.jpg', 'num': 6812.7},
#  {'filename': 'hefei_3872.jpg.jpg', 'num': 3204.4},
#  {'filename': 'hefei_3874.jpg.jpg', 'num': 6985.2},
#  {'filename': 'hefei_3876.jpg.jpg', 'num': 2820.1},
#  {'filename': 'hefei_3878.jpg.jpg', 'num': 6095.6},
#  {'filename': 'hefei_3880.jpg.jpg', 'num': 9602.3},
#  {'filename': 'hefei_3881.jpg.jpg', 'num': 6101.9},
#  {'filename': 'hefei_3882.jpg.jpg', 'num': 2866.6},
#  {'filename': 'hefei_3884.jpg.jpg', 'num': 8109.3},
#  {'filename': 'hefei_3886.jpg.jpg', 'num': 12355.4},
#  {'filename': 'hefei_3888.jpg.jpg', 'num': 2243.1},
#  {'filename': 'hefei_3889.jpg.jpg', 'num': 3964.5},
#  {'filename': 'hefei_3890.jpg.jpg', 'num': 2168.2},
#  {'filename': 'hefei_3892.jpg.jpg', 'num': 6435.9},
#  {'filename': 'hefei_3894.jpg.jpg', 'num': 2381.8},
#  {'filename': 'hefei_3897.jpg.jpg', 'num': 2610.7},
#  {'filename': 'hefei_3898.jpg.jpg', 'num': 7727.5},
#  {'filename': 'hefei_3904.jpg.jpg', 'num': 7636.5},
#  {'filename': 'hefei_3906.jpg.jpg', 'num': 7225.7},
#  {'filename': 'hefei_3908.jpg.jpg', 'num': 5967.5},
#  {'filename': 'hefei_3909.jpg.jpg', 'num': 12331.9},
#  {'filename': 'hefei_3910.jpg.jpg', 'num': 7212.9},
#  {'filename': 'hefei_3913.jpg.jpg', 'num': 2583.0},
#  {'filename': 'hefei_3916.jpg.jpg', 'num': 6780.3},
#  {'filename': 'hefei_3917.jpg.jpg', 'num': 6840.1},
#  {'filename': 'hefei_3920.jpg.jpg', 'num': 6988.7},
#  {'filename': 'hefei_3921.jpg.jpg', 'num': 6042.4},
#  {'filename': 'hefei_3925.jpg.jpg', 'num': 1414.9},
#  {'filename': 'hefei_3928.jpg.jpg', 'num': 3396.0},
#  {'filename': 'hefei_3929.jpg.jpg', 'num': 10321.2},
#  {'filename': 'hefei_3930.jpg.jpg', 'num': 29.0},
#  {'filename': 'hefei_3933.jpg.jpg', 'num': 7714.2},
#  {'filename': 'hefei_3936.jpg.jpg', 'num': 11339.9},
#  {'filename': 'hefei_3937.jpg.jpg', 'num': 5962.0},
#  {'filename': 'hefei_3938.jpg.jpg', 'num': 3110.6},
#  {'filename': 'hefei_3940.jpg.jpg', 'num': 7089.3},
#  {'filename': 'hefei_3941.jpg.jpg', 'num': 2702.6},
#  {'filename': 'hefei_3942.jpg.jpg', 'num': 8266.8},
#  {'filename': 'hefei_3944.jpg.jpg', 'num': 5760.1},
#  {'filename': 'hefei_3945.jpg.jpg', 'num': 935.0},
#  {'filename': 'hefei_3946.jpg.jpg', 'num': 6328.1},
#  {'filename': 'hefei_3948.jpg.jpg', 'num': 6015.3},
#  {'filename': 'hefei_3949.jpg.jpg', 'num': 6484.2},
#  {'filename': 'hefei_3950.jpg.jpg', 'num': 7545.5},
#  {'filename': 'hefei_3954.jpg.jpg', 'num': 3421.6},
#  {'filename': 'hefei_3956.jpg.jpg', 'num': 8169.2},
#  {'filename': 'hefei_3957.jpg.jpg', 'num': 5172.9},
#  {'filename': 'hefei_3958.jpg.jpg', 'num': 4460.3},
#  {'filename': 'hefei_3960.jpg.jpg', 'num': 916.5},
#  {'filename': 'hefei_3961.jpg.jpg', 'num': 20427.7},
#  {'filename': 'hefei_3962.jpg.jpg', 'num': 12706.0},
#  {'filename': 'hefei_3964.jpg.jpg', 'num': 7719.3},
#  {'filename': 'hefei_3965.jpg.jpg', 'num': 3702.2},
#  {'filename': 'hefei_3968.jpg.jpg', 'num': 3932.3},
#  {'filename': 'hefei_3970.jpg.jpg', 'num': 14104.4},
#  {'filename': 'hefei_3972.jpg.jpg', 'num': 5883.2},
#  {'filename': 'hefei_3973.jpg.jpg', 'num': 2420.0},
#  {'filename': 'hefei_3974.jpg.jpg', 'num': 5782.5},
#  {'filename': 'hefei_3977.jpg.jpg', 'num': 11259.6},
#  {'filename': 'hefei_3982.jpg.jpg', 'num': 3281.7},
#  {'filename': 'hefei_3986.jpg.jpg', 'num': 1573.2},
#  {'filename': 'hefei_3988.jpg.jpg', 'num': 6119.6},
#  {'filename': 'hefei_3989.jpg.jpg', 'num': 2232.5},
#  {'filename': 'hefei_3990.jpg.jpg', 'num': 7294.8},
#  {'filename': 'hefei_3996.jpg.jpg', 'num': 11534.2},
#  {'filename': 'hefei_3998.jpg.jpg', 'num': 2288.3},
#  {'filename': 'hefei_4000.jpg.jpg', 'num': 6093.1},
#  {'filename': 'hefei_4002.jpg.jpg', 'num': 3161.8},
#  {'filename': 'hefei_4004.jpg.jpg', 'num': 6010.8},
#  {'filename': 'hefei_4005.jpg.jpg', 'num': 4425.8},
#  {'filename': 'hefei_4009.jpg.jpg', 'num': 592.6},
#  {'filename': 'hefei_4010.jpg.jpg', 'num': 6480.4},
#  {'filename': 'hefei_4012.jpg.jpg', 'num': 1620.9},
#  {'filename': 'hefei_4014.jpg.jpg', 'num': 6003.7},
#  {'filename': 'hefei_4018.jpg.jpg', 'num': 8367.7},
#  {'filename': 'hefei_4020.jpg.jpg', 'num': 3068.8},
#  {'filename': 'hefei_4021.jpg.jpg', 'num': 2569.6},
#  {'filename': 'hefei_4024.jpg.jpg', 'num': 3021.7},
#  {'filename': 'hefei_4025.jpg.jpg', 'num': 41911.4},
#  {'filename': 'hefei_4026.jpg.jpg', 'num': 2859.7},
#  {'filename': 'hefei_4028.jpg.jpg', 'num': 1730.2},
#  {'filename': 'hefei_4029.jpg.jpg', 'num': 7326.3},
#  {'filename': 'hefei_4030.jpg.jpg', 'num': 9334.9},
#  {'filename': 'hefei_4032.jpg.jpg', 'num': 6345.2},
#  {'filename': 'hefei_4037.jpg.jpg', 'num': 5869.1},
#  {'filename': 'hefei_4038.jpg.jpg', 'num': 7817.9},
#  {'filename': 'hefei_4042.jpg.jpg', 'num': 7462.2},
#  {'filename': 'hefei_4045.jpg.jpg', 'num': 3421.8},
#  {'filename': 'hefei_4047.jpg.jpg', 'num': 27521.7},
#  {'filename': 'hefei_4049.jpg.jpg', 'num': 6948.4},
#  {'filename': 'hefei_4050.jpg.jpg', 'num': 3657.7},
#  {'filename': 'hefei_4051.jpg.jpg', 'num': 3292.1},
#  {'filename': 'hefei_4055.jpg.jpg', 'num': 7111.0},
#  {'filename': 'hefei_4057.jpg.jpg', 'num': 3335.5},
#  {'filename': 'hefei_4058.jpg.jpg', 'num': 6015.8},
#  {'filename': 'hefei_4061.jpg.jpg', 'num': 2181.6},
#  {'filename': 'hefei_4062.jpg.jpg', 'num': 7827.2},
#  {'filename': 'hefei_4063.jpg.jpg', 'num': 6826.6},
#  {'filename': 'hefei_4065.jpg.jpg', 'num': 2438.2},
#  {'filename': 'hefei_4066.jpg.jpg', 'num': 1158.0},
#  {'filename': 'hefei_4069.jpg.jpg', 'num': 4163.8},
#  {'filename': 'hefei_4070.jpg.jpg', 'num': 6870.1},
#  {'filename': 'hefei_4071.jpg.jpg', 'num': 6191.7},
#  {'filename': 'hefei_4073.jpg.jpg', 'num': 6168.2},
#  {'filename': 'hefei_4074.jpg.jpg', 'num': 7180.4},
#  {'filename': 'hefei_4075.jpg.jpg', 'num': 7786.5},
#  {'filename': 'hefei_4077.jpg.jpg', 'num': 5846.5},
#  {'filename': 'hefei_4081.jpg.jpg', 'num': 7568.4},
#  {'filename': 'hefei_4082.jpg.jpg', 'num': 5158.2},
#  {'filename': 'hefei_4083.jpg.jpg', 'num': 1491.6},
#  {'filename': 'hefei_4086.jpg.jpg', 'num': 12400.3},
#  {'filename': 'hefei_4089.jpg.jpg', 'num': 4056.8},
#  {'filename': 'hefei_4090.jpg.jpg', 'num': 2882.4},
#  {'filename': 'hefei_4093.jpg.jpg', 'num': 5541.1},
#  {'filename': 'hefei_4094.jpg.jpg', 'num': 6356.9},
#  {'filename': 'hefei_4095.jpg.jpg', 'num': 1011.7},
#  {'filename': 'hefei_4097.jpg.jpg', 'num': 6021.7},
#  {'filename': 'hefei_4098.jpg.jpg', 'num': 7120.5},
#  {'filename': 'hefei_4099.jpg.jpg', 'num': 6058.3},
#  {'filename': 'hefei_4101.jpg.jpg', 'num': 2565.2},
#  {'filename': 'hefei_4102.jpg.jpg', 'num': 26225.6},
#  {'filename': 'hefei_4103.jpg.jpg', 'num': 5289.6},
#  {'filename': 'hefei_4105.jpg.jpg', 'num': 8582.4},
#  {'filename': 'hefei_4109.jpg.jpg', 'num': 9362.1},
#  {'filename': 'hefei_4110.jpg.jpg', 'num': 3330.0},
#  {'filename': 'hefei_4111.jpg.jpg', 'num': 8463.3},
#  {'filename': 'hefei_4113.jpg.jpg', 'num': 2555.7},
#  {'filename': 'hefei_4114.jpg.jpg', 'num': 7505.6},
#  {'filename': 'hefei_4115.jpg.jpg', 'num': 1971.0},
#  {'filename': 'hefei_4117.jpg.jpg', 'num': 3234.0},
#  {'filename': 'hefei_4118.jpg.jpg', 'num': 1302.8},
#  {'filename': 'hefei_4121.jpg.jpg', 'num': 2939.4},
#  {'filename': 'hefei_4125.jpg.jpg', 'num': 1758.6},
#  {'filename': 'hefei_4127.jpg.jpg', 'num': 5999.6},
#  {'filename': 'hefei_4129.jpg.jpg', 'num': 5447.3},
#  {'filename': 'hefei_4131.jpg.jpg', 'num': 4666.6},
#  {'filename': 'hefei_4133.jpg.jpg', 'num': 2359.9},
#  {'filename': 'hefei_4135.jpg.jpg', 'num': 7764.3},
#  {'filename': 'hefei_4138.jpg.jpg', 'num': 8943.6},
#  {'filename': 'hefei_4139.jpg.jpg', 'num': 5109.5},
#  {'filename': 'hefei_4141.jpg.jpg', 'num': 5522.6},
#  {'filename': 'hefei_4142.jpg.jpg', 'num': 7849.9},
#  {'filename': 'hefei_4143.jpg.jpg', 'num': 1760.2},
#  {'filename': 'hefei_4145.jpg.jpg', 'num': 11351.9},
#  {'filename': 'hefei_4146.jpg.jpg', 'num': 2168.2},
#  {'filename': 'hefei_4147.jpg.jpg', 'num': 9409.2},
#  {'filename': 'hefei_4149.jpg.jpg', 'num': 5965.1},
#  {'filename': 'hefei_4150.jpg.jpg', 'num': 7189.9},
#  {'filename': 'hefei_4151.jpg.jpg', 'num': 5127.3},
#  {'filename': 'hefei_4153.jpg.jpg', 'num': 6733.6},
#  {'filename': 'hefei_4154.jpg.jpg', 'num': 4114.0},
#  {'filename': 'hefei_4155.jpg.jpg', 'num': 5981.0},
#  {'filename': 'hefei_4161.jpg.jpg', 'num': 4393.6},
#  {'filename': 'hefei_4162.jpg.jpg', 'num': 5611.7},
#  {'filename': 'hefei_4163.jpg.jpg', 'num': 6978.3},
#  {'filename': 'hefei_4165.jpg.jpg', 'num': 2609.2},
#  {'filename': 'hefei_4166.jpg.jpg', 'num': 8805.3},
#  {'filename': 'hefei_4167.jpg.jpg', 'num': 5739.1},
#  {'filename': 'hefei_4170.jpg.jpg', 'num': 6071.4},
#  {'filename': 'hefei_4171.jpg.jpg', 'num': 3208.9},
#  {'filename': 'hefei_4173.jpg.jpg', 'num': 3748.3},
#  {'filename': 'hefei_4175.jpg.jpg', 'num': 2508.5},
#  {'filename': 'hefei_4178.jpg.jpg', 'num': 9728.0},
#  {'filename': 'hefei_4181.jpg.jpg', 'num': 2144.2},
#  {'filename': 'hefei_4183.jpg.jpg', 'num': 7520.1},
#  {'filename': 'hefei_4185.jpg.jpg', 'num': 4086.1},
#  {'filename': 'hefei_4186.jpg.jpg', 'num': 3705.2},
#  {'filename': 'hefei_4187.jpg.jpg', 'num': 1434.7},
#  {'filename': 'hefei_4189.jpg.jpg', 'num': 1108.5},
#  {'filename': 'hefei_4190.jpg.jpg', 'num': 1247.6},
#  {'filename': 'hefei_4191.jpg.jpg', 'num': 6831.6},
#  {'filename': 'hefei_4193.jpg.jpg', 'num': 2675.0},
#  {'filename': 'hefei_4194.jpg.jpg', 'num': 8741.3},
#  {'filename': 'hefei_4195.jpg.jpg', 'num': 1832.5},
#  {'filename': 'hefei_4197.jpg.jpg', 'num': 1715.3},
#  {'filename': 'hefei_4198.jpg.jpg', 'num': 5954.8},
#  {'filename': 'hefei_4199.jpg.jpg', 'num': 6768.4},
#  {'filename': 'hefei_4201.jpg.jpg', 'num': 3469.3},
#  {'filename': 'hefei_4202.jpg.jpg', 'num': 5943.1},
#  {'filename': 'hefei_4203.jpg.jpg', 'num': 1412.1},
#  {'filename': 'hefei_4206.jpg.jpg', 'num': 14558.3},
#  {'filename': 'hefei_4207.jpg.jpg', 'num': 8420.3},
#  {'filename': 'hefei_4209.jpg.jpg', 'num': 5887.5},
#  {'filename': 'hefei_4210.jpg.jpg', 'num': 6002.6},
#  {'filename': 'hefei_4211.jpg.jpg', 'num': 2388.8},
#  {'filename': 'hefei_4213.jpg.jpg', 'num': 7785.8},
#  {'filename': 'hefei_4214.jpg.jpg', 'num': 163.3},
#  {'filename': 'hefei_4215.jpg.jpg', 'num': 8613.8},
#  {'filename': 'hefei_4217.jpg.jpg', 'num': 2979.5},
#  {'filename': 'hefei_4218.jpg.jpg', 'num': 15128.1},
#  {'filename': 'hefei_4219.jpg.jpg', 'num': 4057.1},
#  {'filename': 'hefei_4221.jpg.jpg', 'num': 3570.5},
#  {'filename': 'hefei_4222.jpg.jpg', 'num': 2370.8},
#  {'filename': 'hefei_4223.jpg.jpg', 'num': 2246.7},
#  {'filename': 'hefei_4225.jpg.jpg', 'num': 3078.0},
#  {'filename': 'hefei_4226.jpg.jpg', 'num': 4215.0},
#  {'filename': 'hefei_4227.jpg.jpg', 'num': 6043.4},
#  {'filename': 'hefei_4230.jpg.jpg', 'num': 7389.0},
#  {'filename': 'hefei_4231.jpg.jpg', 'num': 9896.4},
#  {'filename': 'hefei_4233.jpg.jpg', 'num': 6806.6},
#  {'filename': 'hefei_4234.jpg.jpg', 'num': 5892.2},
#  {'filename': 'hefei_4237.jpg.jpg', 'num': 10189.5},
#  {'filename': 'hefei_4238.jpg.jpg', 'num': 14210.1},
#  {'filename': 'hefei_4241.jpg.jpg', 'num': 6845.8},
#  {'filename': 'hefei_4242.jpg.jpg', 'num': 1697.8},
#  {'filename': 'hefei_4245.jpg.jpg', 'num': 6052.6},
#  {'filename': 'hefei_4251.jpg.jpg', 'num': 2085.1},
#  {'filename': 'hefei_4255.jpg.jpg', 'num': 7184.6},
#  {'filename': 'hefei_4256.jpg.jpg', 'num': 4317.5},
#  {'filename': 'hefei_4258.jpg.jpg', 'num': 1800.0},
#  {'filename': 'hefei_4260.jpg.jpg', 'num': 14121.1},
#  {'filename': 'hefei_4262.jpg.jpg', 'num': 10613.0},
#  {'filename': 'hefei_4263.jpg.jpg', 'num': 6828.5},
#  {'filename': 'hefei_4266.jpg.jpg', 'num': 11068.9},
#  {'filename': 'hefei_4267.jpg.jpg', 'num': 6443.3},
#  {'filename': 'hefei_4270.jpg.jpg', 'num': 1858.2},
#  {'filename': 'hefei_4271.jpg.jpg', 'num': 14746.7},
#  {'filename': 'hefei_4274.jpg.jpg', 'num': 2618.5},
#  {'filename': 'hefei_4275.jpg.jpg', 'num': 18591.7},
#  {'filename': 'hefei_4276.jpg.jpg', 'num': 8469.3},
#  {'filename': 'hefei_4279.jpg.jpg', 'num': 3719.8},
#  {'filename': 'hefei_4280.jpg.jpg', 'num': 6688.6},
#  {'filename': 'hefei_4282.jpg.jpg', 'num': 6492.0},
#  {'filename': 'hefei_4283.jpg.jpg', 'num': 0.30000000000000004},
#  {'filename': 'hefei_4284.jpg.jpg', 'num': 3106.8},
#  {'filename': 'hefei_4286.jpg.jpg', 'num': 4519.2},
#  {'filename': 'hefei_4287.jpg.jpg', 'num': 2570.8},
#  {'filename': 'hefei_4288.jpg.jpg', 'num': 5552.9},
#  {'filename': 'hefei_4290.jpg.jpg', 'num': 9427.8},
#  {'filename': 'hefei_4291.jpg.jpg', 'num': 3502.2},
#  {'filename': 'hefei_4292.jpg.jpg', 'num': 7119.5},
#  {'filename': 'hefei_4294.jpg.jpg', 'num': 6218.3},
#  {'filename': 'hefei_4299.jpg.jpg', 'num': 4468.3},
#  {'filename': 'hefei_4302.jpg.jpg', 'num': 6905.0},
#  {'filename': 'hefei_4304.jpg.jpg', 'num': 3235.3},
#  {'filename': 'hefei_4306.jpg.jpg', 'num': 2570.8},
#  {'filename': 'hefei_4310.jpg.jpg', 'num': 2846.2},
#  {'filename': 'hefei_4311.jpg.jpg', 'num': 3953.7},
#  {'filename': 'hefei_4312.jpg.jpg', 'num': 4211.6},
#  {'filename': 'hefei_4314.jpg.jpg', 'num': 2627.8},
#  {'filename': 'hefei_4315.jpg.jpg', 'num': 3700.0},
#  {'filename': 'hefei_4316.jpg.jpg', 'num': 9641.0},
#  {'filename': 'hefei_4318.jpg.jpg', 'num': 4116.7},
#  {'filename': 'hefei_4324.jpg.jpg', 'num': 6854.0},
#  {'filename': 'hefei_4328.jpg.jpg', 'num': 6285.6},
#  {'filename': 'hefei_4330.jpg.jpg', 'num': 6428.3},
#  {'filename': 'hefei_4332.jpg.jpg', 'num': 2807.1},
#  {'filename': 'hefei_4335.jpg.jpg', 'num': 11065.0},
#  {'filename': 'hefei_4338.jpg.jpg', 'num': 6896.2},
#  {'filename': 'hefei_4340.jpg.jpg', 'num': 6148.2},
#  {'filename': 'hefei_4342.jpg.jpg', 'num': 3461.6},
#  {'filename': 'hefei_4343.jpg.jpg', 'num': 5135.3},
#  {'filename': 'hefei_4344.jpg.jpg', 'num': 1142.6},
#  {'filename': 'hefei_4346.jpg.jpg', 'num': 5622.1},
#  {'filename': 'hefei_4347.jpg.jpg', 'num': 3074.5},
#  {'filename': 'hefei_4350.jpg.jpg', 'num': 38493.2},
#  {'filename': 'hefei_4351.jpg.jpg', 'num': 3277.2},
#  {'filename': 'hefei_4352.jpg.jpg', 'num': 9832.5},
#  {'filename': 'hefei_4354.jpg.jpg', 'num': 1274.5},
#  {'filename': 'hefei_4355.jpg.jpg', 'num': 3203.0},
#  {'filename': 'hefei_4359.jpg.jpg', 'num': 3197.7},
#  {'filename': 'hefei_4360.jpg.jpg', 'num': 1510.8},
#  {'filename': 'hefei_4362.jpg.jpg', 'num': 2290.9},
#  {'filename': 'hefei_4363.jpg.jpg', 'num': 10335.1},
#  {'filename': 'hefei_4366.jpg.jpg', 'num': 10876.1},
#  {'filename': 'hefei_4367.jpg.jpg', 'num': 10139.5},
#  {'filename': 'hefei_4368.jpg.jpg', 'num': 4649.8},
#  {'filename': 'hefei_4372.jpg.jpg', 'num': 2407.2},
#  {'filename': 'hefei_4374.jpg.jpg', 'num': 3061.8},
#  {'filename': 'hefei_4375.jpg.jpg', 'num': 1520.8},
#  {'filename': 'hefei_4378.jpg.jpg', 'num': 1641.0},
#  {'filename': 'hefei_4380.jpg.jpg', 'num': 6380.8},
#  {'filename': 'hefei_4382.jpg.jpg', 'num': 29659.4},
#  {'filename': 'hefei_4383.jpg.jpg', 'num': 8422.5},
#  {'filename': 'hefei_4384.jpg.jpg', 'num': 3234.3},
#  {'filename': 'hefei_4386.jpg.jpg', 'num': 446.3},
#  {'filename': 'hefei_4387.jpg.jpg', 'num': 6708.3},
#  {'filename': 'hefei_4390.jpg.jpg', 'num': 10942.7},
#  {'filename': 'hefei_4391.jpg.jpg', 'num': 2961.7},
#  {'filename': 'hefei_4394.jpg.jpg', 'num': 14852.3},
#  {'filename': 'hefei_4395.jpg.jpg', 'num': 2381.1},
#  {'filename': 'hefei_4396.jpg.jpg', 'num': 5457.5},
#  {'filename': 'hefei_4398.jpg.jpg', 'num': 3282.4},
#  {'filename': 'hefei_4399.jpg.jpg', 'num': 2646.2},
#  {'filename': 'hefei_4400.jpg.jpg', 'num': 2551.6},
#  {'filename': 'hefei_4403.jpg.jpg', 'num': 2425.3},
#  {'filename': 'hefei_4404.jpg.jpg', 'num': 4595.2},
#  {'filename': 'hefei_4408.jpg.jpg', 'num': 38116.2},
#  {'filename': 'hefei_4413.jpg.jpg', 'num': 1704.7},
#  {'filename': 'hefei_4415.jpg.jpg', 'num': 7740.6},
#  {'filename': 'hefei_4416.jpg.jpg', 'num': 5892.6},
#  {'filename': 'hefei_4419.jpg.jpg', 'num': 1684.5},
#  {'filename': 'hefei_4420.jpg.jpg', 'num': 5988.1},
#  {'filename': 'hefei_4423.jpg.jpg', 'num': 7793.9},
#  {'filename': 'hefei_4427.jpg.jpg', 'num': 2516.3},
#  {'filename': 'hefei_4429.jpg.jpg', 'num': 7602.1},
#  {'filename': 'hefei_4431.jpg.jpg', 'num': 10208.0},
#  {'filename': 'hefei_4432.jpg.jpg', 'num': 4011.1},
#  {'filename': 'hefei_4433.jpg.jpg', 'num': 6429.8},
#  {'filename': 'hefei_4435.jpg.jpg', 'num': 1621.6},
#  {'filename': 'hefei_4437.jpg.jpg', 'num': 5812.8},
#  {'filename': 'hefei_4440.jpg.jpg', 'num': 6592.6},
#  {'filename': 'hefei_4441.jpg.jpg', 'num': 3155.1},
#  {'filename': 'hefei_4447.jpg.jpg', 'num': 6022.9},
#  {'filename': 'hefei_4451.jpg.jpg', 'num': 3364.9},
#  {'filename': 'hefei_4452.jpg.jpg', 'num': 2170.2},
#  {'filename': 'hefei_4453.jpg.jpg', 'num': 13940.0},
#  {'filename': 'hefei_4455.jpg.jpg', 'num': 1912.5},
#  {'filename': 'hefei_4457.jpg.jpg', 'num': 7490.3},
#  {'filename': 'hefei_4459.jpg.jpg', 'num': 3684.0},
#  {'filename': 'hefei_4464.jpg.jpg', 'num': 1476.6},
#  {'filename': 'hefei_4465.jpg.jpg', 'num': 3398.4},
#  {'filename': 'hefei_4468.jpg.jpg', 'num': 3110.8},
#  {'filename': 'hefei_4469.jpg.jpg', 'num': 7746.2},
#  {'filename': 'hefei_4471.jpg.jpg', 'num': 8353.0},
#  {'filename': 'hefei_4472.jpg.jpg', 'num': 3647.3},
#  {'filename': 'hefei_4473.jpg.jpg', 'num': 2179.5},
#  {'filename': 'hefei_4475.jpg.jpg', 'num': 3554.5},
#  {'filename': 'hefei_4476.jpg.jpg', 'num': 6761.3},
#  {'filename': 'hefei_4477.jpg.jpg', 'num': 2852.4},
#  {'filename': 'hefei_4479.jpg.jpg', 'num': 6109.1},
#  {'filename': 'hefei_4483.jpg.jpg', 'num': 2993.2},
#  {'filename': 'hefei_4484.jpg.jpg', 'num': 2204.2},
#  {'filename': 'hefei_4485.jpg.jpg', 'num': 2945.5},
#  {'filename': 'hefei_4488.jpg.jpg', 'num': 16685.8},
#  {'filename': 'hefei_4489.jpg.jpg', 'num': 2821.2},
#  {'filename': 'hefei_4491.jpg.jpg', 'num': 3895.6},
#  {'filename': 'hefei_4492.jpg.jpg', 'num': 4321.7},
#  {'filename': 'hefei_4493.jpg.jpg', 'num': 5172.4},
#  {'filename': 'hefei_4495.jpg.jpg', 'num': 3402.2},
#  {'filename': 'hefei_4496.jpg.jpg', 'num': 2407.1},
#  {'filename': 'hefei_4497.jpg.jpg', 'num': 2681.7},
#  {'filename': 'hefei_4501.jpg.jpg', 'num': 4348.5},
#  {'filename': 'hefei_4503.jpg.jpg', 'num': 6691.1},
#  {'filename': 'hefei_4504.jpg.jpg', 'num': 3086.9},
#  {'filename': 'hefei_4505.jpg.jpg', 'num': 3898.0},
#  {'filename': 'hefei_4508.jpg.jpg', 'num': 20618.0},
#  {'filename': 'hefei_4509.jpg.jpg', 'num': 7630.0},
#  {'filename': 'hefei_4513.jpg.jpg', 'num': 29402.1},
#  {'filename': 'hefei_4515.jpg.jpg', 'num': 3230.7},
#  {'filename': 'hefei_4516.jpg.jpg', 'num': 2961.3},
#  {'filename': 'hefei_4524.jpg.jpg', 'num': 4219.1},
#  {'filename': 'hefei_4528.jpg.jpg', 'num': 4044.4},
#  {'filename': 'hefei_4529.jpg.jpg', 'num': 5367.8}]

# %%
# 训练模型并自动保存
model, save_path = train_auto(data_root='train', save_dir='models')

# 打印保存路径
print(f"模型已保存至: {save_path}")
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 开始训练模型，保存路径: models\training_20250527_161850
# Epoch 1/10, Loss: 0.5282, Acc: 82.76%
# Best model saved with accuracy: 82.76%
# Epoch 2/10, Loss: 0.1319, Acc: 95.99%
# Best model saved with accuracy: 95.99%
# Epoch 3/10, Loss: 0.0778, Acc: 97.66%
# Best model saved with accuracy: 97.66%
# Epoch 4/10, Loss: 0.0718, Acc: 97.79%
# Best model saved with accuracy: 97.79%
# Epoch 5/10, Loss: 0.0689, Acc: 97.91%
# Best model saved with accuracy: 97.91%
# Epoch 6/10, Loss: 0.0401, Acc: 98.65%
# Best model saved with accuracy: 98.65%
# Epoch 7/10, Loss: 0.0378, Acc: 98.95%
# Best model saved with accuracy: 98.95%
# Epoch 8/10, Loss: 0.0309, Acc: 99.15%
# Best model saved with accuracy: 99.15%
# Epoch 9/10, Loss: 0.0320, Acc: 99.03%
# Epoch 10/10, Loss: 0.0534, Acc: 98.23%
# Final model saved at: models\training_20250527_161850\final_model.pth
# 评估模型并计算正确率...
# 数字识别详细结果已保存到 models\training_20250527_161850/digital_cut.csv
#
# 模型整体正确率: 99.76%
# 拼接完整电表读数...
# 拼接后的电表读数已保存到 train/digital_compair.csv
# 模型已保存至: models\training_20250527_161850
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# AlexNetEnhanced(
#   (alexnet): AlexNet(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): ResidualBlock(
#         (conv1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential()
#       )
#       (7): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=192, out_features=12, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=12, out_features=192, bias=False)
#           (3): Sigmoid()
#         )
#       )
#       (8): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): ResidualBlock(
#         (conv1): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential()
#       )
#       (11): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=384, out_features=24, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=24, out_features=384, bias=False)
#           (3): Sigmoid()
#         )
#       )
#       (12): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): ReLU(inplace=True)
#       (14): ResidualBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential()
#       )
#       (15): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#       (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (17): ReLU(inplace=True)
#       (18): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#     (classifier): Sequential(
#       (0): Dropout(p=0.5, inplace=False)
#       (1): Linear(in_features=9216, out_features=2048, bias=True)
#       (2): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#       (4): Dropout(p=0.5, inplace=False)
#       (5): Linear(in_features=2048, out_features=10, bias=True)
#     )
#   )
# )

# %%
# 测试函数
def test_auto(data_root='test'):
    test_dir=f'{data_root}/cut_num'
    
    results = process_meter_images('test')
    
    print(f"处理完成，共处理{len(results)}张图像")
    # 数据预处理
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    
    # 加载数据集
    dataset = MeterDigitDataset(root_dir=test_dir, transform=transform)
    dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
    
    # 评估模型并保存详细结果
    print("评估模型并计算正确率...")
    results = evaluate_and_save_results(model, dataloader,data_root='test')
    
    # 计算整体正确率
    if results:
        total_predictions = len(results)
        correct_predictions = sum(1 for item in results if item['预测'] == item['实际'])
        accuracy = (correct_predictions / total_predictions) * 100
        print(f"\n模型整体正确率: {accuracy:.2f}%")
    
    # 从详细结果拼接完整电表读数
    print("拼接完整电表读数...")
    combine_digits_from_csv('test')

# %%
import pandas as pd

def calculate_accuracy(data_root='train'):
    # 读取原始数据和预测结果
    truth_csv=f'{data_root}/data.csv'
    pred_csv=f'{data_root}/digital_compair.csv'
    df_truth = pd.read_csv(truth_csv)
    df_pred = pd.read_csv(pred_csv)
    
    # 数据清洗：处理文件名后缀问题（如.hefei_3188.jpg.jpg）
    df_truth['filename'] = df_truth['filename'].str.replace('.jpg.jpg', '.jpg')  # 处理重复后缀
    df_pred['filename'] = df_pred['filename'].str.replace('.jpg.jpg', '.jpg')
    
    # 合并真实值和预测值
    merged_df = pd.merge(df_truth, df_pred, on='filename', how='inner')
    
    # 检查数据是否匹配
    if len(merged_df) == 0:
        print("警告：未找到匹配的文件")
        return 0.0
    
    # 计算绝对误差和正确率
    merged_df['truth_number'] = merged_df['number'].astype(float)
    merged_df['pred_number'] = merged_df['num'].astype(float)
    
    # 定义允许的误差范围（根据需求调整，此处以绝对误差<=0.5为例）
    merged_df['is_correct'] = np.abs(merged_df['truth_number'] - merged_df['pred_number']) <= 0.5
    
    # 计算整体正确率
    accuracy = merged_df['is_correct'].mean() * 100
    
    # 输出详细结果
    print("数据匹配结果：")
    print(merged_df[['filename', 'truth_number', 'pred_number', 'is_correct']])
    print(f"\n整体正确率：{accuracy:.2f}%")
    
    return accuracy

# 运行示例
if __name__ == "__main__":
    calculate_accuracy()
# Out:
# 数据匹配结果：
#            filename  truth_number  pred_number  is_correct
# 0    hefei_3191.jpg        2262.7       2262.7        True
# 1    hefei_3195.jpg        7509.7       7509.7        True
# 2    hefei_3198.jpg       18304.5      18304.5        True
# 3    hefei_3203.jpg        1923.0       1912.0       False
# 4    hefei_3221.jpg        4135.3       4135.3        True
# ..              ...           ...          ...         ...
# 162  hefei_4479.jpg        6109.1       6109.1        True
# 163  hefei_4496.jpg        2407.1       2407.1        True
# 164  hefei_4497.jpg        2681.7       2681.7        True
# 165  hefei_4515.jpg        3230.7       3230.7        True
# 166  hefei_4516.jpg        2961.3       2961.4        True
#
# [167 rows x 4 columns]
#
# 整体正确率：92.81%

# %%
def convert_filename_to_id(data_root='train'):
    """
    将CSV文件中的filename列转换为纯数字ID列
    
    参数:
    - csv_path: 输入CSV文件路径（包含filename列）
    - output_path: 输出CSV文件路径（默认为原文件添加'_converted'后缀）
    
    返回:
    - 处理后的DataFrame
    """
    csv_path = f'{data_root}/digital_compair.csv'
    output_path=f'{data_root}/digital_out.csv'
    # 读取CSV文件
    df = pd.read_csv(csv_path)
    
    # 确保存在filename列
    if 'filename' not in df.columns:
        raise ValueError(f"CSV文件中未找到'filename'列: {csv_path}")
    
    # 从filename提取数字ID（处理可能的.jpg.jpg后缀）
    df['ID'] = df['filename'].apply(lambda x: 
        x.split('_')[-1]           # 提取最后一部分（如3188.jpg.jpg）
        .replace('.jpg', '')      # 移除.jpg后缀
        .split('.')[0]            # 处理可能的剩余后缀（如3188.jpg.jpg → 3188）
    )
    
    # 重命名列并调整顺序
    if 'num' in df.columns:
        df = df.rename(columns={'num': 'number'})  # 若存在num列，重命名为number
    
    # 确保输出包含ID和number列
    if not all(col in df.columns for col in ['ID', 'number']):
        raise ValueError("CSV文件中缺少必要的列（filename和num/number）")
    
    # 保存结果
    if output_path is None:
        # 默认在原文件名后添加_converted
        output_path = csv_path.replace('.csv', '_converted.csv')
    
    df[['ID', 'number']].to_csv(output_path, index=False)
    print(f"已将filename转换为ID并保存至: {output_path}")
    
    return df

# %%
convert_filename_to_id()
# Out:
# 已将filename转换为ID并保存至: train/digital_out.csv
#                filename   number    ID
# 0    hefei_3191.jpg.jpg   2262.7  3191
# 1    hefei_3195.jpg.jpg   7509.7  3195
# 2    hefei_3198.jpg.jpg  18304.5  3198
# 3    hefei_3203.jpg.jpg   1912.0  3203
# 4    hefei_3221.jpg.jpg   4135.3  3221
# ..                  ...      ...   ...
# 162  hefei_4479.jpg.jpg   6109.1  4479
# 163  hefei_4496.jpg.jpg   2407.1  4496
# 164  hefei_4497.jpg.jpg   2681.7  4497
# 165  hefei_4515.jpg.jpg   3230.7  4515
# 166  hefei_4516.jpg.jpg   2961.4  4516
#
# [167 rows x 3 columns]

# %%
# 测试模块,加载训练好的模型

# 后续使用时加载模型
model = AlexNetEnhanced(num_classes=10)
model.load_state_dict(torch.load(os.path.join(save_path, 'best_model.pth')))
model.eval()  # 设置为评估模式

print(save_path)

test_auto()
convert_filename_to_id('test')
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# models\training_20250527_161850
# 成功处理: hefei_3191.jpg -> 022627
# 成功处理: hefei_3195.jpg -> 075097
# 成功处理: hefei_3198.jpg -> 183045
# 成功处理: hefei_3203.jpg -> 019230
# 成功处理: hefei_3221.jpg -> 041353
# 成功处理: hefei_3229.jpg -> 030739
# 成功处理: hefei_3230.jpg -> 126352
# 成功处理: hefei_3232.jpg -> 050302
# 成功处理: hefei_3242.jpg -> 063963
# 成功处理: hefei_3256.jpg -> 023339
# 成功处理: hefei_3262.jpg -> 072279
# 成功处理: hefei_3274.jpg -> 063205
# 成功处理: hefei_3277.jpg -> 128458
# 成功处理: hefei_3278.jpg -> 061333
# 成功处理: hefei_3280.jpg -> 032190
# 成功处理: hefei_3288.jpg -> 077486
# 成功处理: hefei_3293.jpg -> 018402
# 成功处理: hefei_3294.jpg -> 099083
# 成功处理: hefei_3296.jpg -> 037952
# 成功处理: hefei_3300.jpg -> 100138
# 成功处理: hefei_3304.jpg -> 031438
# 成功处理: hefei_3306.jpg -> 066856
# 成功处理: hefei_3320.jpg -> 150017
# 成功处理: hefei_3321.jpg -> 031565
# 成功处理: hefei_3326.jpg -> 035753
# 成功处理: hefei_3337.jpg -> 042082
# 成功处理: hefei_3338.jpg -> 101854
# 成功处理: hefei_3349.jpg -> 028278
# 成功处理: hefei_3352.jpg -> 052763
# 成功处理: hefei_3374.jpg -> 083449
# 成功处理: hefei_3377.jpg -> 011703
# 成功处理: hefei_3399.jpg -> 022572
# 成功处理: hefei_3418.jpg -> 215913
# 成功处理: hefei_3426.jpg -> 204323
# 成功处理: hefei_3450.jpg -> 122347
# 成功处理: hefei_3455.jpg -> 026067
# 成功处理: hefei_3458.jpg -> 057844
# 成功处理: hefei_3466.jpg -> 034106
# 成功处理: hefei_3471.jpg -> 020636
# 成功处理: hefei_3472.jpg -> 019763
# 成功处理: hefei_3474.jpg -> 039709
# 成功处理: hefei_3475.jpg -> 039457
# 成功处理: hefei_3476.jpg -> 109975
# 成功处理: hefei_3480.jpg -> 075435
# 成功处理: hefei_3484.jpg -> 032122
# 成功处理: hefei_3497.jpg -> 067966
# 成功处理: hefei_3513.jpg -> 066023
# 成功处理: hefei_3520.jpg -> 039643
# 成功处理: hefei_3524.jpg -> 112938
# 成功处理: hefei_3528.jpg -> 069497
# 成功处理: hefei_3533.jpg -> 123431
# 成功处理: hefei_3540.jpg -> 111133
# 成功处理: hefei_3561.jpg -> 243988
# 成功处理: hefei_3569.jpg -> 071950
# 成功处理: hefei_3576.jpg -> 145728
# 成功处理: hefei_3583.jpg -> 138076
# 成功处理: hefei_3584.jpg -> 087082
# 成功处理: hefei_3587.jpg -> 151125
# 成功处理: hefei_3589.jpg -> 074266
# 成功处理: hefei_3593.jpg -> 029576
# 成功处理: hefei_3595.jpg -> 049738
# 成功处理: hefei_3609.jpg -> 110786
# 成功处理: hefei_3615.jpg -> 179210
# 成功处理: hefei_3617.jpg -> 031652
# 成功处理: hefei_3631.jpg -> 064298
# 成功处理: hefei_3633.jpg -> 006084
# 成功处理: hefei_3640.jpg -> 140446
# 成功处理: hefei_3641.jpg -> 035672
# 成功处理: hefei_3652.jpg -> 030322
# 成功处理: hefei_3655.jpg -> 116250
# 成功处理: hefei_3657.jpg -> 025985
# 成功处理: hefei_3663.jpg -> 034931
# 成功处理: hefei_3665.jpg -> 058271
# 成功处理: hefei_3672.jpg -> 048466
# 成功处理: hefei_3676.jpg -> 074502
# 成功处理: hefei_3677.jpg -> 076884
# 成功处理: hefei_3680.jpg -> 032292
# 成功处理: hefei_3687.jpg -> 117284
# 成功处理: hefei_3696.jpg -> 157457
# 成功处理: hefei_3736.jpg -> 180131
# 成功处理: hefei_3752.jpg -> 062071
# 成功处理: hefei_3756.jpg -> 073677
# 成功处理: hefei_3759.jpg -> 041078
# 成功处理: hefei_3768.jpg -> 045677
# 成功处理: hefei_3771.jpg -> 036097
# 成功处理: hefei_3775.jpg -> 096880
# 成功处理: hefei_3781.jpg -> 124939
# 成功处理: hefei_3783.jpg -> 060487
# 成功处理: hefei_3787.jpg -> 035526
# 成功处理: hefei_3792.jpg -> 072499
# 成功处理: hefei_3793.jpg -> 069571
# 成功处理: hefei_3796.jpg -> 072124
# 成功处理: hefei_3800.jpg -> 227464
# 成功处理: hefei_3805.jpg -> 112464
# 成功处理: hefei_3816.jpg -> 059431
# 成功处理: hefei_3819.jpg -> 116269
# 成功处理: hefei_3823.jpg -> 067271
# 成功处理: hefei_3838.jpg -> 023009
# 成功处理: hefei_3842.jpg -> 070067
# 成功处理: hefei_3846.jpg -> 019736
# 成功处理: hefei_3865.jpg -> 021399
# 成功处理: hefei_3866.jpg -> 138360
# 成功处理: hefei_3898.jpg -> 077275
# 成功处理: hefei_3906.jpg -> 072257
# 成功处理: hefei_3913.jpg -> 025830
# 成功处理: hefei_3937.jpg -> 059620
# 成功处理: hefei_3942.jpg -> 082668
# 成功处理: hefei_3944.jpg -> 057601
# 成功处理: hefei_3945.jpg -> 009350
# 成功处理: hefei_3958.jpg -> 044603
# 成功处理: hefei_3961.jpg -> 204277
# 成功处理: hefei_3968.jpg -> 039323
# 成功处理: hefei_3988.jpg -> 061196
# 成功处理: hefei_3989.jpg -> 022325
# 成功处理: hefei_4010.jpg -> 064804
# 成功处理: hefei_4014.jpg -> 060037
# 成功处理: hefei_4057.jpg -> 033355
# 成功处理: hefei_4073.jpg -> 061682
# 成功处理: hefei_4081.jpg -> 075684
# 成功处理: hefei_4101.jpg -> 025652
# 成功处理: hefei_4105.jpg -> 085824
# 成功处理: hefei_4110.jpg -> 033300
# 成功处理: hefei_4111.jpg -> 084633
# 成功处理: hefei_4114.jpg -> 075056
# 成功处理: hefei_4129.jpg -> 054473
# 成功处理: hefei_4139.jpg -> 051095
# 成功处理: hefei_4163.jpg -> 069783
# 成功处理: hefei_4165.jpg -> 026092
# 成功处理: hefei_4178.jpg -> 097280
# 成功处理: hefei_4181.jpg -> 021442
# 成功处理: hefei_4191.jpg -> 068336
# 成功处理: hefei_4194.jpg -> 087413
# 成功处理: hefei_4197.jpg -> 017153
# 成功处理: hefei_4201.jpg -> 034693
# 成功处理: hefei_4203.jpg -> 034121
# 成功处理: hefei_4221.jpg -> 035705
# 成功处理: hefei_4230.jpg -> 073890
# 成功处理: hefei_4231.jpg -> 098964
# 成功处理: hefei_4233.jpg -> 068066
# 成功处理: hefei_4238.jpg -> 142301
# 成功处理: hefei_4260.jpg -> 141211
# 成功处理: hefei_4287.jpg -> 025708
# 成功处理: hefei_4318.jpg -> 041167
# 成功处理: hefei_4332.jpg -> 028071
# 成功处理: hefei_4342.jpg -> 034616
# 成功处理: hefei_4344.jpg -> 033426
# 成功处理: hefei_4347.jpg -> 030745
# 成功处理: hefei_4355.jpg -> 032030
# 成功处理: hefei_4360.jpg -> 015308
# 成功处理: hefei_4363.jpg -> 103351
# 成功处理: hefei_4375.jpg -> 015208
# 成功处理: hefei_4413.jpg -> 017047
# 成功处理: hefei_4416.jpg -> 058926
# 成功处理: hefei_4420.jpg -> 059881
# 成功处理: hefei_4431.jpg -> 102080
# 成功处理: hefei_4432.jpg -> 040111
# 成功处理: hefei_4437.jpg -> 058128
# 成功处理: hefei_4441.jpg -> 031551
# 成功处理: hefei_4447.jpg -> 060229
# 成功处理: hefei_4451.jpg -> 033649
# 成功处理: hefei_4455.jpg -> 019125
# 成功处理: hefei_4464.jpg -> 014766
# 成功处理: hefei_4479.jpg -> 061091
# 成功处理: hefei_4496.jpg -> 024071
# 成功处理: hefei_4497.jpg -> 026817
# 成功处理: hefei_4515.jpg -> 032307
# 成功处理: hefei_4516.jpg -> 029613
# 处理完成，共处理167张图像
# 评估模型并计算正确率...
# 数字识别详细结果已保存到 test/digital_cut.csv
#
# 模型整体正确率: 98.40%
# 拼接完整电表读数...
# 拼接后的电表读数已保存到 test/digital_compair.csv
# 已将filename转换为ID并保存至: test/digital_out.csv
#                filename   number    ID
# 0    hefei_3191.jpg.jpg   2262.7  3191
# 1    hefei_3195.jpg.jpg   7509.7  3195
# 2    hefei_3198.jpg.jpg  18304.5  3198
# 3    hefei_3203.jpg.jpg   1923.0  3203
# 4    hefei_3221.jpg.jpg   4135.3  3221
# ..                  ...      ...   ...
# 162  hefei_4479.jpg.jpg   6109.1  4479
# 163  hefei_4496.jpg.jpg   2407.1  4496
# 164  hefei_4497.jpg.jpg   2681.7  4497
# 165  hefei_4515.jpg.jpg   3230.7  4515
# 166  hefei_4516.jpg.jpg   2961.3  4516
#
# [167 rows x 3 columns]

# %% [markdown]
# ### AlexNet模型结构详解
#
# AlexNet是2012年ImageNet竞赛冠军模型，由Alex Krizhevsky等人提出。它是深度卷积神经网络在计算机视觉领域的里程碑，首次证明了深度网络在大规模图像分类任务上的有效性。
#
# 以下是我针对电表数字识别任务修改后的AlexNet模型结构及关键组件说明：
#
# ### 1. 整体架构概述
#
# 我的实现基于预训练的AlexNet模型，保留了原始的卷积特征提取部分，仅修改了最后的全连接分类器以适应0-9数字识别任务：
#
# ```python
# class AlexNetModified(nn.Module):
#     def __init__(self, num_classes=10):
#         super(AlexNetModified, self).__init__()
#         self.alexnet = models.alexnet(pretrained=True)
#
#         # 冻结大部分预训练层
#         for param in list(self.alexnet.parameters())[:-5]:
#             param.requires_grad = False
#
#         # 修改分类器
#         self.alexnet.classifier = nn.Sequential(
#             nn.Dropout(),
#             nn.Linear(256 * 6 * 6, 4096),
#             nn.ReLU(inplace=True),
#             nn.Dropout(),
#             nn.Linear(4096, 4096),
#             nn.ReLU(inplace=True),
#             nn.Linear(4096, num_classes),
#         )
#
#     def forward(self, x):
#         return self.alexnet(x)
# ```
#
# ### 2. 卷积层与池化层配置
#
# AlexNet的卷积部分包含5个卷积层和3个最大池化层，具体配置如下：
#
# ```
# 输入图像: 3通道, 224x224像素
#
# 1. 卷积层1 (Conv1):
#    - 卷积核数量: 64
#    - 卷积核大小: 11x11
#    - 步长: 4
#    - 填充: 2
#    - 激活函数: ReLU
#    - 输出尺寸: (64, 55, 55)
#
# 2. 最大池化层1 (MaxPool1):
#    - 池化核大小: 3x3
#    - 步长: 2
#    - 输出尺寸: (64, 27, 27)
#
# 3. 卷积层2 (Conv2):
#    - 卷积核数量: 192
#    - 卷积核大小: 5x5
#    - 步长: 1
#    - 填充: 2
#    - 激活函数: ReLU
#    - 输出尺寸: (192, 27, 27)
#
# 4. 最大池化层2 (MaxPool2):
#    - 池化核大小: 3x3
#    - 步长: 2
#    - 输出尺寸: (192, 13, 13)
#
# 5. 卷积层3 (Conv3):
#    - 卷积核数量: 384
#    - 卷积核大小: 3x3
#    - 步长: 1
#    - 填充: 1
#    - 激活函数: ReLU
#    - 输出尺寸: (384, 13, 13)
#
# 6. 卷积层4 (Conv4):
#    - 卷积核数量: 256
#    - 卷积核大小: 3x3
#    - 步长: 1
#    - 填充: 1
#    - 激活函数: ReLU
#    - 输出尺寸: (256, 13, 13)
#
# 7. 卷积层5 (Conv5):
#    - 卷积核数量: 256
#    - 卷积核大小: 3x3
#    - 步长: 1
#    - 填充: 1
#    - 激活函数: ReLU
#    - 输出尺寸: (256, 13, 13)
#
# 8. 最大池化层3 (MaxPool3):
#    - 池化核大小: 3x3
#    - 步长: 2
#    - 输出尺寸: (256, 6, 6)
# ```
#
# ### 3. 全连接层配置
#
# 原始AlexNet的全连接层包含3个层，我针对数字识别任务进行了修改：
#
# ```
# 1. 扁平化操作:
#    - 将卷积输出(256, 6, 6)展平为一维向量: 256 * 6 * 6 = 9216
#
# 2. 全连接层1 (FC1):
#    - 输入特征: 9216
#    - 输出特征: 4096
#    - 激活函数: ReLU
#    - Dropout: 0.5 (训练时随机丢弃50%的神经元)
#
# 3. 全连接层2 (FC2):
#    - 输入特征: 4096
#    - 输出特征: 4096
#    - 激活函数: ReLU
#    - Dropout: 0.5
#
# 4. 输出层 (Output):
#    - 输入特征: 4096
#    - 输出特征: 10 (对应数字0-9)
#    - 无激活函数(原始输出，后续由Softmax处理)
# ```
#
# ### 4. 损失函数与优化器
#
# 在训练过程中，我使用了以下配置：
#
# ```python
# # 损失函数: 交叉熵损失
# criterion = nn.CrossEntropyLoss()
#
# # 优化器: 随机梯度下降(SGD)
# optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# ```
#
# **交叉熵损失函数**(CrossEntropyLoss)的数学表达式：
# ```
# L = -1/N * Σ(y_i * log(p_i))
# ```
# 其中：
# - N是批量大小
# - y_i是真实标签的one-hot编码
# - p_i是模型预测的概率分布
# - log是自然对数
#
# 这个损失函数结合了Softmax激活和负对数似然损失，特别适合多分类问题。它会惩罚模型对正确类别的低置信度预测。
#
# ### 5. 设计思路与优化策略
#
# 1. **预训练模型利用**：
#    - 使用ImageNet预训练权重初始化模型，大幅提高小数据集上的性能
#    - 冻结前几层卷积层(保留通用特征)，只训练后几层适应特定任务
#
# 2. **正则化处理**：
#    - 在全连接层使用Dropout(0.5)减少过拟合
#    - 输入图像进行标准化处理，提高模型稳定性
#
# 3. **计算效率优化**：
#    - 冻结大部分预训练层参数，只需训练约5%的模型参数
#    - 输入图像尺寸为224x224，平衡精度和计算速度
#
# 4. **输出层设计**：
#    - 最后一层全连接输出10个类别，对应数字0-9
#    - 使用交叉熵损失函数，天然适合多分类任务
#
# 这个网络设计充分利用了AlexNet的强大特征提取能力，同时针对电表数字识别任务进行了优化，能够高效准确地识别切割后的数字图像。
